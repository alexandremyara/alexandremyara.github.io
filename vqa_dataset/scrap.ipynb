# %% [markdown]
# ## Import

# %%
import json
import csv
import requests
from bs4 import BeautifulSoup
import os
from selenium import webdriver
from time import sleep
import shutil
from tqdm import tqdm
DATA_PATH = "data_annotatedv2"

# %% [markdown]
# ## Scraper

# %%
def load_html(url:str, static=True) :
    """
    Load a BeautifulSoup instance over an HTML page.
    If static=False, we use Selenium to load the page.
    If static=True, we use requests to load the page.
    Input :
    url: str, url of the page
    static: bool
    """

    if static :
        response = requests.get(url)
        return BeautifulSoup(response.content, "html.parser")
    else :
        driver = webdriver.Firefox()
        driver.get(url)
        sleep(5)
        html = driver.page_source
        soup = BeautifulSoup(html, "html.parser")
        driver.quit()
        return soup

# %%
def extract_urls_from_search(search_url) :
    urls=[]
    soup = load_html(search_url, False)
    for tag in soup.find_all("a", href=True) :
        if "from_search" in tag["href"] : urls.append(tag["href"])
    return urls

# %%
def extract_most_read(slideshow: dict) -> list :
    """
    Construct a one-hot vector of length nb_slides. Put a 1 at the index of slides most read.
    Inputs :
    slideshow: dict, metadata of the slideshow (extracted with BeautifulSoup)
    Ouputs :
    isMostRead: list, one-hot vector of nb_slides 
    """
    nb_slides = slideshow["totalSlides"]
    indexMostRead = [list(slide.items())[0][1] for slide in slideshow["topReadSlides"]]
    isMostRead = [1 if k in indexMostRead else 0 for k in range(nb_slides)]
    return isMostRead

# %%
def scrap(url:str) :
    """
    The scrap function slides from SlideShare.net and then creates a folder which contains all slides in jpg format.
    Input :
    url : a str-like, contains the url of the download page of the slides
    """
    #html request
    soup = load_html(url)

    #The script tag with id "__NETX_DATA__" contains with a json format some meta informations.
    data = json.loads(soup.select_one("#__NEXT_DATA__").text)
    slideshow =  data["props"]["pageProps"]["slideshow"]

    if type(slideshow["transcript"]) == str : transcript = [slideshow["transcript"]]
    else : transcript = slideshow["transcript"]

    meta_data = { "id": slideshow["id"],
                  "presentation_url": slideshow["canonicalUrl"],
                  "title": slideshow["title"],
                  "author": slideshow["username"],
                  "date": slideshow["createdAt"][:10], #AAAA-MM-JJ
                  "len": slideshow["totalSlides"],
                  "description": slideshow["description"],
                  "lang": slideshow["language"],
                  "dim": slideshow["slideDimensions"],
                  "like": slideshow["likes"],
                  "view": slideshow["views"],
                  "transcript": transcript,
                  "mostRead": extract_most_read(slideshow),
                  }
    #img_urls
    slides = slideshow["slides"]
    sizes = slides["imageSizes"][1]
    img_url = f"{slides['host']}/{slides['imageLocation']}/{sizes['quality']}/{slideshow['title']}-" + "{}" + f"-{sizes['width']}.{sizes['format']}"

    #folder creation
    folder_name = str(slideshow["id"])
    if not os.path.exists(DATA_PATH) : os.mkdir(DATA_PATH)
    if os.path.exists(DATA_PATH+"/"+folder_name) : shutil.rmtree(DATA_PATH+"/"+folder_name)
    os.mkdir(DATA_PATH+"/"+folder_name)
    
    #For each image
    for i in range(slideshow["totalSlides"]):
        response = requests.get(img_url.format(i+1))
        sleep(5)
        with open(f"{DATA_PATH}/{folder_name}/slide_{i}.jpg", "wb") as f :
            f.write(response.content)
            
    with open(f"{DATA_PATH}/{folder_name}/{folder_name.lower()}.json", "w") as f :
        json.dump(meta_data,f)

# %% [markdown]
# ## Test

# %%
soup = load_html("https://fr.slideshare.net/slideshow/repas-franais-46412448/46412448?from_search=0")
json.loads(soup.select_one("#__NEXT_DATA__").text)["props"]["pageProps"]["slideshow"]
# Out:
# {'username': 'nuriagulieva',
#  'id': '46412448',
#  'allowDownloads': True,
#  'allowDownloadOriginalFile': True,
#  'allowEmbeds': True,
#  'categories': [{'id': '29', 'name': 'Alimentation', 'url': 'food'}],
#  'canonicalUrl': 'https://fr.slideshare.net/slideshow/repas-franais-46412448/46412448',
#  'createdAt': '2015-03-29 05:05:30 UTC',
#  'description': 'Repas Français.',
#  'downloadKey': '8703f5a6fc289d34e0013d3d7dd616716ae6ee086966beb9c6b3657a64bbb94e',
#  'editorsNotes': [],
#  'extension': 'pptx',
#  'genaiTest': 'control',
#  'genaiDescriptionCreatedAt': None,
#  'iframeEmbed': {'url': 'https://www.slideshare.net/slideshow/embed_code/key/gQmo6wGfATUguS',
#   'height': 486,
#   'width': 597},
#  'isIndexable': True,
#  'isPrivate': False,
#  'isViewable': True,
#  'language': 'fr',
#  'likes': 2,
#  'isLikedByCurrentUser': False,
#  'recommendationsByLocation': {'rightRail': [{'algorithmId': '5',
#     'displayTitle': 'La Gastronomie En France',
#     'isSavedByCurrentUser': False,
#     'pageCount': 68,
#     'score': 0.749205,
#     'slideshowId': '28639045',
#     'sourceName': 'cm_interact',
#     'strippedTitle': 'la-gastronomie-en-france',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lagastronomieenfranceforafrances-131126084457-phpapp01-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'Presentación de la gastronomía de Francia en general.\r\nIES Foramontanos - 4ºESO',
#     'tags': [],
#     'url': 'https://fr.slideshare.net/slideshow/la-gastronomie-en-france/28639045',
#     'userLogin': 'FrancesForamontanos',
#     'userName': 'FrancesForamontanos',
#     'viewCount': 19326},
#    {'algorithmId': '5',
#     'displayTitle': 'Gastronomie',
#     'isSavedByCurrentUser': False,
#     'pageCount': 14,
#     'score': 0.700836,
#     'slideshowId': '268439',
#     'sourceName': 'cm_interact',
#     'strippedTitle': 'gastronomie',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/gastronomie-1203183040327270-2-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': '',
#     'tags': [],
#     'url': 'https://fr.slideshare.net/MariolaMoreno/gastronomie',
#     'userLogin': 'MariolaMoreno',
#     'userName': 'MariolaMoreno',
#     'viewCount': 5596},
#    {'algorithmId': '5',
#     'displayTitle': 'La gastronomie francaise',
#     'isSavedByCurrentUser': False,
#     'pageCount': 23,
#     'score': 0.689961,
#     'slideshowId': '61996999',
#     'sourceName': 'cm_interact',
#     'strippedTitle': 'la-gastronomie-francaise',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/projetfrengjishtejeblertabasha-160513184904-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'La gastronomie francaise\r\n',
#     'tags': [],
#     'url': 'https://fr.slideshare.net/koralda/la-gastronomie-francaise',
#     'userLogin': 'koralda',
#     'userName': 'koralda',
#     'viewCount': 5403},
#    {'algorithmId': '5',
#     'displayTitle': 'La cuisine francaise',
#     'isSavedByCurrentUser': False,
#     'pageCount': 12,
#     'score': 0.6759,
#     'slideshowId': '15581308',
#     'sourceName': 'cm_interact',
#     'strippedTitle': 'la-cuisine-francaise',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lacuisinefrancaise-121210205814-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': '',
#     'tags': [],
#     'url': 'https://fr.slideshare.net/slideshow/la-cuisine-francaise/15581308',
#     'userLogin': 'sitnikova26',
#     'userName': 'sitnikova26',
#     'viewCount': 3119},
#    {'algorithmId': '5',
#     'displayTitle': 'La Gastronomie FrançAise',
#     'isSavedByCurrentUser': False,
#     'pageCount': 35,
#     'score': 0.6678,
#     'slideshowId': '2423540',
#     'sourceName': 'cm_interact',
#     'strippedTitle': 'la-gastronomie-franaise-2423540',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lagastronomiefranaise-091104144714-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'Présentation des plats typiques de la France',
#     'tags': [],
#     'url': 'https://www.slideshare.net/slideshow/la-gastronomie-franaise-2423540/2423540',
#     'userLogin': 'Belami77',
#     'userName': 'Ismael Navarro Solera',
#     'viewCount': 44281},
#    {'algorithmId': '5',
#     'displayTitle': 'Des specialites francaises',
#     'isSavedByCurrentUser': False,
#     'pageCount': 15,
#     'score': 0.598386,
#     'slideshowId': '62216749',
#     'sourceName': 'cm_interact',
#     'strippedTitle': 'des-specialites-francaises',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/desspecialitesfrancaises-160520080801-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'Présentation de 7 recettes de la cuisine française très connues',
#     'tags': ['sites web', 'cuisine', 'recette'],
#     'url': 'https://fr.slideshare.net/akossyv/des-specialites-francaises',
#     'userLogin': 'akossyv',
#     'userName': 'Athina KOSSYVAKI',
#     'viewCount': 2466},
#    {'algorithmId': '5',
#     'displayTitle': 'Les plats typiques français',
#     'isSavedByCurrentUser': False,
#     'pageCount': 57,
#     'score': 0.598227,
#     'slideshowId': '32281238',
#     'sourceName': 'cm_interact',
#     'strippedTitle': 'les-plats-typiques-franais-32281238',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lesplatstypiquesfranais-140313123950-phpapp01-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': '',
#     'tags': [],
#     'url': 'https://www.slideshare.net/slideshow/les-plats-typiques-franais-32281238/32281238',
#     'userLogin': 'robertoruizetslayo1999',
#     'userName': 'robertoruizetslayo1999',
#     'viewCount': 30606},
#    {'algorithmId': '5',
#     'displayTitle': 'Les repas en france',
#     'isSavedByCurrentUser': False,
#     'pageCount': 7,
#     'score': 0.597923,
#     'slideshowId': '11684541',
#     'sourceName': 'cm_interact',
#     'strippedTitle': 'les-repas-en-france-11684541',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lesrepasenfrance-120221013542-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': '',
#     'tags': [],
#     'url': 'https://fr.slideshare.net/slideshow/les-repas-en-france-11684541/11684541',
#     'userLogin': 'mrubiobilingual',
#     'userName': 'mrubiobilingual',
#     'viewCount': 26478}],
#   'whatsHot': [{'algorithmId': '5',
#     'displayTitle': 'French  Food',
#     'isSavedByCurrentUser': False,
#     'pageCount': 19,
#     'score': 0.587842,
#     'slideshowId': '9550188',
#     'sourceName': 'cm_interact',
#     'strippedTitle': 'french-food-9550188',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/frenchfoodpresentation-111004221228-phpapp01-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'The document discusses French food culture, including typical elements of a French menu such as appetizers, main courses featuring fish, vegetables, meat and starches, cheese courses featuring brie and camembert, dessert, and drinks like coffee, wine and mineral water. It also notes what French people typically have for breakfast, lunch, and dinner, with main meals centered around traditional dishes and cheeses accompanied by bread.',
#     'tags': [],
#     'url': 'https://www.slideshare.net/slideshow/french-food-9550188/9550188',
#     'userLogin': 'AndyQuinteroMacea',
#     'userName': 'Andrés Quintero Macea',
#     'viewCount': 6710},
#    {'algorithmId': '5',
#     'displayTitle': 'French cuisine',
#     'isSavedByCurrentUser': False,
#     'pageCount': 22,
#     'score': 0.568604,
#     'slideshowId': '29468013',
#     'sourceName': 'cm_interact',
#     'strippedTitle': 'french-cuisine-29468013',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/frenchcuisine-131224051324-phpapp01-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': "French cuisine originated in France and was later codified by Georges Auguste Escoffier in the 20th century. French food is diverse due to France's varied geography and history. Meals can range from simple fare like bread and wine to elaborate affairs involving multiple courses over several hours. Regional influences on French food include local ingredients, neighboring countries, history, and immigration. Common cooking styles are classical French, haute cuisine, cuisine nouvelle, and cuisine du terroir focused on regional specialties. Key ingredients in French meals include bread, wine, cheese, and a structured meal typically involves a breakfast, lunch, and dinner consisting of multiple courses.",
#     'tags': [],
#     'url': 'https://www.slideshare.net/slideshow/french-cuisine-29468013/29468013',
#     'userLogin': 'moocsengine',
#     'userName': 'Moocs Engine',
#     'viewCount': 13954},
#    {'algorithmId': '5',
#     'displayTitle': 'Les parties du corps',
#     'isSavedByCurrentUser': False,
#     'pageCount': 16,
#     'score': 0.564611,
#     'slideshowId': '19778793',
#     'sourceName': 'cm_interact',
#     'strippedTitle': 'partiesducorps',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/partiesducorps-130423103422-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'Vocabulaire pour apprendre quelques parties du corps, pour les élèves que commençent à étudier le français',
#     'tags': ['parties du corps'],
#     'url': 'https://fr.slideshare.net/slideshow/partiesducorps/19778793',
#     'userLogin': 'pakyrata',
#     'userName': 'pakyrata',
#     'viewCount': 129349},
#    {'algorithmId': '5',
#     'displayTitle': "Quand j'étais petit(e)...",
#     'isSavedByCurrentUser': False,
#     'pageCount': 3,
#     'score': 0.562937,
#     'slideshowId': '10531656',
#     'sourceName': 'cm_interact',
#     'strippedTitle': 'quand-jtais-petite',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/quandjtaispetit-111209080221-phpapp01-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': '',
#     'tags': [],
#     'url': 'https://fr.slideshare.net/slideshow/quand-jtais-petite/10531656',
#     'userLogin': 'LLeadley',
#     'userName': 'LLeadley',
#     'viewCount': 37415},
#    {'algorithmId': '5',
#     'displayTitle': 'Le Passé Composé',
#     'isSavedByCurrentUser': False,
#     'pageCount': 17,
#     'score': 0.55786,
#     'slideshowId': '1277131',
#     'sourceName': 'cm_interact',
#     'strippedTitle': 'le-pass-compos-1277131',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lepasscompos-090412040719-phpapp01-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': "Formation du Passé Composé: formation, emploi des auxiliares, la négation, l'interrogation et la place des adverbes.",
#     'tags': ['passé', 'auxiliares', 'participes'],
#     'url': 'https://fr.slideshare.net/slideshow/le-pass-compos-1277131/1277131',
#     'userLogin': 'pmi11',
#     'userName': 'pmi11',
#     'viewCount': 1042136},
#    {'algorithmId': '5',
#     'displayTitle': 'Les sports',
#     'isSavedByCurrentUser': False,
#     'pageCount': 51,
#     'score': 0.55589,
#     'slideshowId': '31771931',
#     'sourceName': 'cm_interact',
#     'strippedTitle': 'les-sports-31771931',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lessports-140228114039-phpapp01-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': '',
#     'tags': [],
#     'url': 'https://fr.slideshare.net/slideshow/les-sports-31771931/31771931',
#     'userLogin': 'departamentofrancesiessigloxxi',
#     'userName': 'departamentofrancesiessigloxxi',
#     'viewCount': 73954},
#    {'algorithmId': '5',
#     'displayTitle': 'La culture française',
#     'isSavedByCurrentUser': False,
#     'pageCount': 30,
#     'score': 0.554635,
#     'slideshowId': '7906266',
#     'sourceName': 'cm_interact',
#     'strippedTitle': 'la-culture-franaise-7906266',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/laculture-110510035142-phpapp01-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'power point para blog de lenguas va la cosa',
#     'tags': [],
#     'url': 'https://fr.slideshare.net/slideshow/la-culture-franaise-7906266/7906266',
#     'userLogin': 'asuncionquesada',
#     'userName': 'asuncionquesada',
#     'viewCount': 21100},
#    {'algorithmId': '5',
#     'displayTitle': 'Francophone countries',
#     'isSavedByCurrentUser': False,
#     'pageCount': 12,
#     'score': 0.553122,
#     'slideshowId': '15212982',
#     'sourceName': 'cm_interact',
#     'strippedTitle': 'francophone-countries',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/francophonecountries-121116124121-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'The document provides information on 14 francophone countries: Quebec, Haiti, Vietnam, Senegal, Cambodia, Madagascar, Luxembourg, Ivory Coast, France, and Monaco. For each country, it lists the capital city, official language(s), government leaders, population, currency, and sometimes other details. The countries covered come from North America, Africa, Asia, and Europe and range in population from around 36,000 (Monaco) to over 87 million (Vietnam). French is the official or co-official language of all the countries listed.',
#     'tags': ['french language', 'languages'],
#     'url': 'https://www.slideshare.net/slideshow/francophone-countries/15212982',
#     'userLogin': 'Markiegee94',
#     'userName': 'Markiegee94',
#     'viewCount': 19034},
#    {'algorithmId': '5',
#     'displayTitle': 'Gastronomie De France',
#     'isSavedByCurrentUser': False,
#     'pageCount': 29,
#     'score': 0.551693,
#     'slideshowId': '427107',
#     'sourceName': 'cm_interact',
#     'strippedTitle': 'gastronomie-de-france',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/gastronimie-de-france-1211728489285887-8-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': '',
#     'tags': ['civilisation', 'civilisation'],
#     'url': 'https://fr.slideshare.net/slideshow/gastronomie-de-france/427107',
#     'userLogin': 'MariolaMoreno',
#     'userName': 'MariolaMoreno',
#     'viewCount': 117789},
#    {'algorithmId': '5',
#     'displayTitle': 'Les repas',
#     'isSavedByCurrentUser': False,
#     'pageCount': 10,
#     'score': 0.548829,
#     'slideshowId': '10918526',
#     'sourceName': 'cm_interact',
#     'strippedTitle': 'les-repas-10918526',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lesrepas-120109155359-phpapp01-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': '',
#     'tags': ['civilisation', 'fle; français'],
#     'url': 'https://fr.slideshare.net/slideshow/les-repas-10918526/10918526',
#     'userLogin': 'cerines',
#     'userName': 'Ines Cerrato',
#     'viewCount': 44526},
#    {'algorithmId': '5',
#     'displayTitle': 'Les repas de la journée',
#     'isSavedByCurrentUser': False,
#     'pageCount': 29,
#     'score': 0.544233,
#     'slideshowId': '75026232',
#     'sourceName': 'cm_interact',
#     'strippedTitle': 'les-repas-de-la-journe-75026232',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lesrepasdelajourne-170414174128-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'Projet eTwinning',
#     'tags': [],
#     'url': 'https://fr.slideshare.net/slideshow/les-repas-de-la-journe-75026232/75026232',
#     'userLogin': 'laurienna',
#     'userName': 'laurienna',
#     'viewCount': 878},
#    {'algorithmId': '5',
#     'displayTitle': 'Clichés et  symboles de France.',
#     'isSavedByCurrentUser': False,
#     'pageCount': 47,
#     'score': 0.542316,
#     'slideshowId': '29299601',
#     'sourceName': 'cm_interact',
#     'strippedTitle': 'clichs-et-symboles-de-france-29299601',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lessymbolesdelafrance-131217151146-phpapp01-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': '',
#     'tags': [],
#     'url': 'https://fr.slideshare.net/slideshow/clichs-et-symboles-de-france-29299601/29299601',
#     'userLogin': 'ProfPapillon',
#     'userName': 'ProfPapillon',
#     'viewCount': 31573},
#    {'algorithmId': '5',
#     'displayTitle': 'Exprimer ses goûts',
#     'isSavedByCurrentUser': False,
#     'pageCount': 5,
#     'score': 0.541418,
#     'slideshowId': '54335960',
#     'sourceName': 'cm_interact',
#     'strippedTitle': 'exprimer-ses-gots-54335960',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/exprimersesgots-151024162515-lva1-app6892-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'Exprimes ses goûts',
#     'tags': [],
#     'url': 'https://fr.slideshare.net/slideshow/exprimer-ses-gots-54335960/54335960',
#     'userLogin': 'Francisca50',
#     'userName': 'Francisca50',
#     'viewCount': 18171},
#    {'algorithmId': '5',
#     'displayTitle': 'Le sport en France ',
#     'isSavedByCurrentUser': False,
#     'pageCount': 8,
#     'score': 0.540918,
#     'slideshowId': '48448024',
#     'sourceName': 'cm_interact',
#     'strippedTitle': 'prezentatsia-microsoft-powerpoint2-48448024',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/prezentatsiamicrosoftpowerpoint2-150521175800-lva1-app6892-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'Le sport en France',
#     'tags': [],
#     'url': 'https://fr.slideshare.net/slideshow/prezentatsia-microsoft-powerpoint2-48448024/48448024',
#     'userLogin': 'rittershprot',
#     'userName': 'rittershprot',
#     'viewCount': 1110},
#    {'algorithmId': '5',
#     'displayTitle': 'Les aliments',
#     'isSavedByCurrentUser': False,
#     'pageCount': 20,
#     'score': 0.53807,
#     'slideshowId': '45432856',
#     'sourceName': 'cm_interact',
#     'strippedTitle': 'les-aliments-45432856',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lesaliments-150304110926-conversion-gate01-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'Vocabulaire',
#     'tags': [],
#     'url': 'https://fr.slideshare.net/slideshow/les-aliments-45432856/45432856',
#     'userLogin': 'Francisca50',
#     'userName': 'Francisca50',
#     'viewCount': 27600},
#    {'algorithmId': '5',
#     'displayTitle': "Lexique les jours de la semaine, les mois de l'année et les saisons",
#     'isSavedByCurrentUser': False,
#     'pageCount': 1,
#     'score': 0.537792,
#     'slideshowId': '120408885',
#     'sourceName': 'cm_interact',
#     'strippedTitle': 'lexique-les-jours-de-la-semaine-les-mois-de-lanne-et-les-saisons',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lesjoursdelasemaine-181023073918-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': "Lexique A1: jours de la semaine, mois de l'année et saisons",
#     'tags': ['les jours de la semaine', "les mois de l'année", 'les saisons'],
#     'url': 'https://www.slideshare.net/slideshow/lexique-les-jours-de-la-semaine-les-mois-de-lanne-et-les-saisons/120408885',
#     'userLogin': 'lebaobabbleu',
#     'userName': 'lebaobabbleu',
#     'viewCount': 46551},
#    {'algorithmId': '5',
#     'displayTitle': 'Französisch Küche',
#     'isSavedByCurrentUser': False,
#     'pageCount': 25,
#     'score': 0.535444,
#     'slideshowId': '69844002',
#     'sourceName': 'cm_interact',
#     'strippedTitle': 'franzsisch-kche',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/microsoftofficepowerpoint-161205180552-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'Französisch Küche',
#     'tags': [],
#     'url': 'https://de.slideshare.net/slideshow/franzsisch-kche/69844002',
#     'userLogin': 'yuliyamickevich',
#     'userName': 'Юлия Мицкевич',
#     'viewCount': 1665},
#    {'algorithmId': '5',
#     'displayTitle': 'Fiche de travail: La cuisine française',
#     'isSavedByCurrentUser': False,
#     'pageCount': 2,
#     'score': 0.534924,
#     'slideshowId': '62240069',
#     'sourceName': 'cm_interact',
#     'strippedTitle': 'fiche-de-travail-la-cuisine-franaise-62240069',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/fichedetravailfrenchcuisine-160520200525-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': "Les élèves à travers les trois activités de la fiche de travail proposée doivent trouver des informations sur quatre recettes de la cuisine française: La salade niçoise, Le coq au vin, La soupe à l'oignon et La quiche lorraine. Ils doivent visiter trois sites web: Cuisine-Française, Wikipedia & Youtube",
#     'tags': ['gastronomie', "la soupe à l'oignon", 'ingredients'],
#     'url': 'https://fr.slideshare.net/akossyv/fiche-de-travail-la-cuisine-franaise-62240069',
#     'userLogin': 'akossyv',
#     'userName': 'Athina KOSSYVAKI',
#     'viewCount': 1326},
#    {'algorithmId': '5',
#     'displayTitle': 'FLE - Aliments - Repas',
#     'isSavedByCurrentUser': False,
#     'pageCount': 7,
#     'score': 0.532523,
#     'slideshowId': '13951717',
#     'sourceName': 'cm_interact',
#     'strippedTitle': 'screen-alimentsrepas',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/screen-aliments-repas-120812163221-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'French vocabulary for the food.',
#     'tags': ['learn french', 'parismonterrey.com', 'aliments'],
#     'url': 'https://fr.slideshare.net/slideshow/screen-alimentsrepas/13951717',
#     'userLogin': 'ParisMonterrey',
#     'userName': 'Nathalie Maguérès',
#     'viewCount': 5057},
#    {'algorithmId': '5',
#     'displayTitle': 'Heures - Quelle heure est-il',
#     'isSavedByCurrentUser': False,
#     'pageCount': 40,
#     'score': 0.532133,
#     'slideshowId': '977958',
#     'sourceName': 'cm_interact',
#     'strippedTitle': 'heures-quelle-heure-estil',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/heuresquelle-heure-estil-1233528128338647-2-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': "FLE - niveau A1 - débutant\r\n1 - Apprendre les heures;\r\n2 - Dire l'heure;\r\n3 - Faire d'autres exercices en ligne.",
#     'tags': [],
#     'url': 'https://fr.slideshare.net/slideshow/heures-quelle-heure-estil/977958',
#     'userLogin': 'marta_santos',
#     'userName': 'Marta Santos',
#     'viewCount': 75330}],
#   'alsoLiked': [{'algorithmId': '21',
#     'displayTitle': 'La cuisine française',
#     'isSavedByCurrentUser': False,
#     'pageCount': 56,
#     'score': 0,
#     'slideshowId': '32236561',
#     'sourceName': 'li_interact',
#     'strippedTitle': 'la-cuisine-franaise-32236561',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lacuisinefranaise-140312133102-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': '',
#     'tags': [],
#     'url': 'https://www.slideshare.net/slideshow/la-cuisine-franaise-32236561/32236561',
#     'userLogin': 'Luciagruiz',
#     'userName': 'Luciagruiz',
#     'viewCount': 3694},
#    {'algorithmId': '21',
#     'displayTitle': 'LA CUISINE FRANÇAISE ',
#     'isSavedByCurrentUser': False,
#     'pageCount': 57,
#     'score': 0,
#     'slideshowId': '32238758',
#     'sourceName': 'li_interact',
#     'strippedTitle': 'la-cuisine-franaise-32238758',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/presentacin1-140312142614-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'LA CUISINE FRANÇAISE \r\n',
#     'tags': ['français la cuisine la cuisine française'],
#     'url': 'https://fr.slideshare.net/slideshow/la-cuisine-franaise-32238758/32238758',
#     'userLogin': 'Mariagarc',
#     'userName': 'Mariagarc',
#     'viewCount': 3374},
#    {'algorithmId': '21',
#     'displayTitle': 'La Cuisine Française',
#     'isSavedByCurrentUser': False,
#     'pageCount': 29,
#     'score': 0,
#     'slideshowId': '48893513',
#     'sourceName': 'li_interact',
#     'strippedTitle': 'la-cuisine-franaise-48893513',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/a-3-3e1751e032a8a6b019c04d0e8e8cad4a679c941c-150602141814-lva1-app6892-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'This short document promotes the creation of Haiku Deck presentations on SlideShare, stating that users can make their own Haiku Deck presentations on the SlideShare platform if they feel inspired. It provides a button to "GET STARTED" in making a Haiku Deck presentation on SlideShare.',
#     'tags': ['haikudeck'],
#     'url': 'https://www.slideshare.net/slideshow/la-cuisine-franaise-48893513/48893513',
#     'userLogin': 'frenchproject1',
#     'userName': 'frenchproject1',
#     'viewCount': 304},
#    {'algorithmId': '21',
#     'displayTitle': '2_francés',
#     'isSavedByCurrentUser': False,
#     'pageCount': 13,
#     'score': 0,
#     'slideshowId': '4614915',
#     'sourceName': 'li_interact',
#     'strippedTitle': '2francs',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/anamaria-100625132434-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': '',
#     'tags': [],
#     'url': 'https://fr.slideshare.net/slideshow/2francs/4614915',
#     'userLogin': 'NuevasTecnolg',
#     'userName': 'NuevasTecnolg',
#     'viewCount': 410},
#    {'algorithmId': '21',
#     'displayTitle': 'La cuisine de français',
#     'isSavedByCurrentUser': False,
#     'pageCount': 16,
#     'score': 0,
#     'slideshowId': '31136230',
#     'sourceName': 'li_interact',
#     'strippedTitle': 'la-cuisine-de-francais',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lacuisinedefrancais-140212125628-phpapp01-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'The French cuisine is extremely diverse and uses fresh, local ingredients. Meals consist of many courses and are a time for socializing. A typical breakfast includes bread, croissants, jam, and butter while lunch varies by region but usually includes wine. Dinner is the main meal, usually consisting of an appetizer, main dish like meat or fish with sides, cheese course, dessert, and coffee. Each course is prepared with care and accompanied by wine. Popular Parisian restaurants emphasize classic French fare or more innovative cooking styles.',
#     'tags': [],
#     'url': 'https://www.slideshare.net/slideshow/la-cuisine-de-francais/31136230',
#     'userLogin': 'cabbott21w',
#     'userName': 'cabbott21w',
#     'viewCount': 1099},
#    {'algorithmId': '21',
#     'displayTitle': 'Le repas gastronomique français',
#     'isSavedByCurrentUser': False,
#     'pageCount': 5,
#     'score': 0,
#     'slideshowId': '10381881',
#     'sourceName': 'li_interact',
#     'strippedTitle': 'le-repas-gastronomique-franais',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lerepasgastronomiquefranais-111129062146-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'Séquence pédagogique NIVEAU A1 sur le repas gastronomique à la française',
#     'tags': ['la carolina', 'a1', 'gastronomie'],
#     'url': 'https://fr.slideshare.net/slideshow/le-repas-gastronomique-franais/10381881',
#     'userLogin': 'IsabelMontesEOI',
#     'userName': 'Escuela Oficial de Idiomas La Carolina, Département de Français',
#     'viewCount': 5351},
#    {'algorithmId': '21',
#     'displayTitle': 'Cuisine francaise',
#     'isSavedByCurrentUser': False,
#     'pageCount': 10,
#     'score': 0,
#     'slideshowId': '9745934',
#     'sourceName': 'li_interact',
#     'strippedTitle': 'cuisine-francaise',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/cuisinefrancaise-111018060012-phpapp01-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': '',
#     'tags': [],
#     'url': 'https://fr.slideshare.net/slideshow/cuisine-francaise/9745934',
#     'userLogin': 'OlgaFernndezOrtega',
#     'userName': 'Olga Fernández Ortega',
#     'viewCount': 986},
#    {'algorithmId': '21',
#     'displayTitle': 'Cultural security in the age of globalization, the case of Middle East',
#     'isSavedByCurrentUser': False,
#     'pageCount': 51,
#     'score': 0,
#     'slideshowId': '47158184',
#     'sourceName': 'li_interact',
#     'strippedTitle': 'cultural-security-in-the-age-of-globalization-the-case-of-middle-east',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/teamwork-150419033327-conversion-gate02-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'People in Middle Eastern countries are concerned that globalization is threatening their culture, language, and traditions. Younger people are especially vulnerable as they increasingly adopt American pop culture through media and consumer products that symbolize concepts like freedom and modernity. Several Middle Eastern governments and media companies have also been introducing Western media to the region. However, some efforts are being made to adapt global influences to local culture, such as through Arabic-dubbed cartoons and movies, and new fashion trends fusing Western and Islamic styles. Researchers are studying how targeting cultural sites has become a tactic in regional conflicts like Syria, and international organizations are working with local experts to protect cultural heritage at risk.',
#     'tags': ['middle east', 'syria', 'isil'],
#     'url': 'https://www.slideshare.net/slideshow/cultural-security-in-the-age-of-globalization-the-case-of-middle-east/47158184',
#     'userLogin': 'nuriagulieva',
#     'userName': 'Nuriyya Guliyeva',
#     'viewCount': 981},
#    {'algorithmId': '21',
#     'displayTitle': 'Family relationships in Asia',
#     'isSavedByCurrentUser': False,
#     'pageCount': 16,
#     'score': 0,
#     'slideshowId': '46412396',
#     'sourceName': 'li_interact',
#     'strippedTitle': 'family-relationships-in-asia',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/familyrelationshipinasia-150329050051-conversion-gate01-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'Asian parents believe that disciplining children and obedience to parents prevents corruption, as explained by a Vietnamese proverb. Traditionally, Asian cultures assign different roles and treatment to girls and boys. Girls are expected to help with childcare and household chores, which can interfere with school attendance, while boys are given more freedom to play. Education was historically prioritized for boys over girls in some Asian cultures.',
#     'tags': ['relationships', 'asia', 'family'],
#     'url': 'https://www.slideshare.net/slideshow/family-relationships-in-asia/46412396',
#     'userLogin': 'nuriagulieva',
#     'userName': 'Nuriyya Guliyeva',
#     'viewCount': 682},
#    {'algorithmId': '21',
#     'displayTitle': 'Reference for Marialis Simoni from Kieran Daly',
#     'isSavedByCurrentUser': False,
#     'pageCount': 1,
#     'score': 0,
#     'slideshowId': '51731822',
#     'sourceName': 'li_interact',
#     'strippedTitle': 'reference-for-marialis-simoni-from-kieran-daly',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/ac35bfca-1b88-43bc-ae60-057ee20d0591-150817182140-lva1-app6892-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': '',
#     'tags': [],
#     'url': 'https://www.slideshare.net/slideshow/reference-for-marialis-simoni-from-kieran-daly/51731822',
#     'userLogin': 'MarialisSimoni',
#     'userName': 'Marialis Simoni',
#     'viewCount': 155},
#    {'algorithmId': '21',
#     'displayTitle': 'Social implications of globalization in Iran',
#     'isSavedByCurrentUser': False,
#     'pageCount': 22,
#     'score': 0,
#     'slideshowId': '45020246',
#     'sourceName': 'li_interact',
#     'strippedTitle': 'social-implications-of-globalization-in-iran',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/socialimplicationsofglobalizationiniran1-150223080647-conversion-gate01-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': "Globalization has impacted Iranian society in several ways. While the government has tried to resist some aspects of globalization to preserve local culture and values, Iranian society has increasingly engaged with global trends and technologies. This has led to changes in employment, migration patterns, gender roles, and family structures. Youth have adopted global media and connectivity, while facing government censorship and restrictions online. Overall, Iranian society has navigated a complex relationship with globalizing forces and local traditions amidst the government's efforts to control cultural changes.",
#     'tags': [],
#     'url': 'https://www.slideshare.net/slideshow/social-implications-of-globalization-in-iran/45020246',
#     'userLogin': 'nuriagulieva',
#     'userName': 'Nuriyya Guliyeva',
#     'viewCount': 3166},
#    {'algorithmId': '21',
#     'displayTitle': 'Academic Reference for Marialis Simoni from Klaus Suhling',
#     'isSavedByCurrentUser': False,
#     'pageCount': 1,
#     'score': 0,
#     'slideshowId': '51731762',
#     'sourceName': 'li_interact',
#     'strippedTitle': 'academic-reference-for-marialis-simoni-from-klaus-suhling',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/4b9a08ea-f4b9-4372-8b2a-0a7a2e71130e-150817182006-lva1-app6892-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'Klaus Suhling is writing a letter of recommendation for Marialis Simoni. Suhling taught Simoni in a first year Physics Skills course, which Simoni regularly attended and obtained an overall first class mark of 79% in. Simoni obtained an average of 82.8% in his first year, coming 7th out of more than 122 students, putting him on course for a first class honors degree. Suhling found Simoni to be a highly motivated, quick learning student who grasps novel ideas well. Suhling also described Simoni as friendly, mature, reliable, and responsible in their dealings, with a personality that makes him pleasant to work with.',
#     'tags': [],
#     'url': 'https://www.slideshare.net/slideshow/academic-reference-for-marialis-simoni-from-klaus-suhling/51731762',
#     'userLogin': 'MarialisSimoni',
#     'userName': 'Marialis Simoni',
#     'viewCount': 1289},
#    {'algorithmId': '21',
#     'displayTitle': 'The archival heritage \x0bof the Middle East. \x0b\x0bCurrent threats and scenarios fo...',
#     'isSavedByCurrentUser': False,
#     'pageCount': 12,
#     'score': 0,
#     'slideshowId': '55776155',
#     'sourceName': 'li_interact',
#     'strippedTitle': 'the-archival-heritage-of-the-middle-east-current-threats-and-scenarios-for-protection-in-the-future',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/thomasaignerworkshopmiddleeast-151203110108-lva1-app6891-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'Presentation by Thomas Aigner (President ICARUS) given within the international workshop "Archive material in the Middle East between menace and solidarity" on 24 November 2015 at the ICARUS-Meeting #16 in St. Pölten (AT).',
#     'tags': ['icarus-meeting', 'thomas aigner', 'icarus-meeting #16'],
#     'url': 'https://www.slideshare.net/slideshow/the-archival-heritage-of-the-middle-east-current-threats-and-scenarios-for-protection-in-the-future/55776155',
#     'userLogin': 'icaruseu',
#     'userName': 'ICARUS - International Centre for Archival Research',
#     'viewCount': 570},
#    {'algorithmId': '21',
#     'displayTitle': 'Academic Reference for Marialis Simoni from Nicola Bonini',
#     'isSavedByCurrentUser': False,
#     'pageCount': 1,
#     'score': 0,
#     'slideshowId': '51731781',
#     'sourceName': 'li_interact',
#     'strippedTitle': 'academic-reference-for-marialis-simoni-from-nicola-bonini',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/a36fe134-9382-4abd-9a74-ea282788067c-150817182035-lva1-app6892-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': "This letter provides a recommendation for Mr. Marialis Simoni from his personal tutor and lecturer Nicola Bonini. The letter states that Mr. Simoni has regularly attended lectures and labs in his first year physics degree at King's College London with great interest and dedication. His performance was excellent, with marks above 90% in multiple courses. The letter strongly supports Mr. Simoni's application and offers to provide any additional information needed.",
#     'tags': [],
#     'url': 'https://www.slideshare.net/slideshow/academic-reference-for-marialis-simoni-from-nicola-bonini/51731781',
#     'userLogin': 'MarialisSimoni',
#     'userName': 'Marialis Simoni',
#     'viewCount': 3480},
#    {'algorithmId': '21',
#     'displayTitle': 'Repas français',
#     'isSavedByCurrentUser': False,
#     'pageCount': 16,
#     'score': 0,
#     'slideshowId': '44458518',
#     'sourceName': 'li_interact',
#     'strippedTitle': 'repas-franais',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/repasfranais-150209133138-conversion-gate01-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'Repas francais',
#     'tags': [],
#     'url': 'https://fr.slideshare.net/slideshow/repas-franais/44458518',
#     'userLogin': 'iessaavedra2011',
#     'userName': 'iessaavedra2011',
#     'viewCount': 2490},
#    {'algorithmId': '21',
#     'displayTitle': 'Cuisine Nationale Azerbaïdjanaise',
#     'isSavedByCurrentUser': False,
#     'pageCount': 11,
#     'score': 0,
#     'slideshowId': '46412518',
#     'sourceName': 'li_interact',
#     'strippedTitle': 'cuisine-nationale-azerbadjanaise',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/cuisinenationaleazerbadjanaise-150329051128-conversion-gate01-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'Cuisine Nationale Azerbaïdjanaise',
#     'tags': [],
#     'url': 'https://www.slideshare.net/slideshow/cuisine-nationale-azerbadjanaise/46412518',
#     'userLogin': 'nuriagulieva',
#     'userName': 'Nuriyya Guliyeva',
#     'viewCount': 727},
#    {'algorithmId': '21',
#     'displayTitle': 'French Presentation',
#     'isSavedByCurrentUser': False,
#     'pageCount': 13,
#     'score': 0,
#     'slideshowId': '15525870',
#     'sourceName': 'li_interact',
#     'strippedTitle': 'french-presentation-15525870',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/frenchpresentation-121206180700-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': '',
#     'tags': [],
#     'url': 'https://fr.slideshare.net/slideshow/french-presentation-15525870/15525870',
#     'userLogin': 'jaimebeck',
#     'userName': 'jaimebeck',
#     'viewCount': 818},
#    {'algorithmId': '21',
#     'displayTitle': 'Academic recommendation letter',
#     'isSavedByCurrentUser': False,
#     'pageCount': 1,
#     'score': 0,
#     'slideshowId': '7675832',
#     'sourceName': 'li_interact',
#     'strippedTitle': 'academic-recommendation-letter',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/scan0414000-13032283536258-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'Recommendation letter from the Dean of Engineering Assistant',
#     'tags': [],
#     'url': 'https://www.slideshare.net/slideshow/academic-recommendation-letter/7675832',
#     'userLogin': 'uzquiano88',
#     'userName': 'Andres',
#     'viewCount': 14781},
#    {'algorithmId': '21',
#     'displayTitle': 'Letters of recomendation',
#     'isSavedByCurrentUser': False,
#     'pageCount': 6,
#     'score': 0,
#     'slideshowId': '3785230',
#     'sourceName': 'li_interact',
#     'strippedTitle': 'letters-of-recomendation',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lettersofrecomendation-100420014611-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': "The document is a letter from Steve Pallister of BP Azerbaijan recommending Water Engineered Technology (WET) for their water filtration and purification systems. BP has used WET's systems for 3 years at their Sangachal Terminal, serving over 5,000 workers. WET has proven themselves with reliable installation, maintenance and monitoring of the systems. Pallister has no hesitation recommending WET's technology and services to other prospective customers.",
#     'tags': ['letters', 'recommendation'],
#     'url': 'https://www.slideshare.net/slideshow/letters-of-recomendation/3785230',
#     'userLogin': 'wetint',
#     'userName': 'Vladimir',
#     'viewCount': 40332},
#    {'algorithmId': '21',
#     'displayTitle': 'Letters Of Recommendation Lpc',
#     'isSavedByCurrentUser': False,
#     'pageCount': 5,
#     'score': 0,
#     'slideshowId': '2403885',
#     'sourceName': 'li_interact',
#     'strippedTitle': 'letters-of-recommendation-lpc-2403885',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lettersofrecommendationlpc-12571801437393-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'Take a look at what previous LoCoco-Pilkington clients had to say about their construction expereince!',
#     'tags': [],
#     'url': 'https://www.slideshare.net/slideshow/letters-of-recommendation-lpc-2403885/2403885',
#     'userLogin': 'lpccon',
#     'userName': 'lpccon',
#     'viewCount': 62085}],
#   'similarTo': [{'algorithmId': '3',
#     'displayTitle': 'La  Gastronomie FrançAise',
#     'isSavedByCurrentUser': False,
#     'pageCount': 17,
#     'score': 0.5176,
#     'slideshowId': '2899222',
#     'sourceName': 'cm_text',
#     'strippedTitle': 'la-gastronomie-franaise-2899222',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lagastronomiefranaise-100112162614-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'Presentation réalisée par Macarena Ortega et Pilar Muñoz',
#     'tags': [],
#     'url': 'https://fr.slideshare.net/slideshow/la-gastronomie-franaise-2899222/2899222',
#     'userLogin': 'francessantacatalina',
#     'userName': 'francessantacatalina',
#     'viewCount': 2223},
#    {'algorithmId': '3',
#     'displayTitle': 'French Culture',
#     'isSavedByCurrentUser': False,
#     'pageCount': 17,
#     'score': 0.5,
#     'slideshowId': '30402628',
#     'sourceName': 'cm_text',
#     'strippedTitle': 'french-culture-30402628',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/french-140124143212-phpapp01-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': '',
#     'tags': ['culture'],
#     'url': 'https://fr.slideshare.net/slideshow/french-culture-30402628/30402628',
#     'userLogin': 'clavinrali',
#     'userName': 'Clavin Rali',
#     'viewCount': 914},
#    {'algorithmId': '3',
#     'displayTitle': 'La gastronomie francaise. Elsa Alcázar. 2ºBc',
#     'isSavedByCurrentUser': False,
#     'pageCount': 49,
#     'score': 0.4742,
#     'slideshowId': '6131828',
#     'sourceName': 'cm_text',
#     'strippedTitle': 'la-gastronomie-francaise-elsa-alczar-2bc',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lagastronomiefrancaise-101212144609-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': '',
#     'tags': ['gastronomie', 'fle', 'eoi'],
#     'url': 'https://fr.slideshare.net/slideshow/la-gastronomie-francaise-elsa-alczar-2bc/6131828',
#     'userLogin': 'asola',
#     'userName': 'asola',
#     'viewCount': 2733},
#    {'algorithmId': '3',
#     'displayTitle': 'Presentación1',
#     'isSavedByCurrentUser': False,
#     'pageCount': 12,
#     'score': 0.4465,
#     'slideshowId': '36003174',
#     'sourceName': 'cm_text',
#     'strippedTitle': 'presentacin1-36003174',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/presentacin1-140618023123-phpapp01-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': '',
#     'tags': [],
#     'url': 'https://fr.slideshare.net/slideshow/presentacin1-36003174/36003174',
#     'userLogin': 'JaimeRomeroBelda',
#     'userName': 'JaimeRomeroBelda',
#     'viewCount': 371},
#    {'algorithmId': '3',
#     'displayTitle': 'COCINA FRANCESA.pptx',
#     'isSavedByCurrentUser': False,
#     'pageCount': 12,
#     'score': 0.3974,
#     'slideshowId': '254613637',
#     'sourceName': 'cm_text',
#     'strippedTitle': 'cocina-francesapptx',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/cocinafrancesa-221130203246-11bf33e3-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'Powerpoint cocina francesa en francés',
#     'tags': [],
#     'url': 'https://fr.slideshare.net/slideshow/cocina-francesapptx/254613637',
#     'userLogin': 'RocioLuisRodriguez',
#     'userName': 'RocioLuisRodriguez',
#     'viewCount': 4},
#    {'algorithmId': '3',
#     'displayTitle': 'projekt la nourriture',
#     'isSavedByCurrentUser': False,
#     'pageCount': 21,
#     'score': 0.396,
#     'slideshowId': '58157554',
#     'sourceName': 'cm_text',
#     'strippedTitle': 'projekt-la-nourriture',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/frengjisht-anxhi-160211162658-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'punoi anxhela gjini \nle sujet:la nourriture',
#     'tags': [],
#     'url': 'https://fr.slideshare.net/slideshow/projekt-la-nourriture/58157554',
#     'userLogin': 'DajanaGjini',
#     'userName': 'Dajana Gjini',
#     'viewCount': 304},
#    {'algorithmId': '3',
#     'displayTitle': 'Yummy magazine N°17',
#     'isSavedByCurrentUser': False,
#     'pageCount': 68,
#     'score': 0.384,
#     'slideshowId': '50207861',
#     'sourceName': 'cm_text',
#     'strippedTitle': 'yummy-magazine-n17',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/yummymagazinen17-150706113252-lva1-app6891-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': "Le premier magazine gratuit, collaboratif et électronique des blogs culinaires. Au sommaire : Naturellement bon - Ils font le buzz : Les choux, L’orange, Les fèves, La mangue, L’ail frais, La rhubarbe - Rencontre avec… Arthur Le Caisne - Vite fait, bien fait ! Au quotidien - Le temps d'un week-end - British Corner - Sans gluten & sans lactose - Zoom sur Les cakes salés et sucrés - Histoire d’épices : La cardamome",
#     'tags': ['food', 'recettes', 'cuisine'],
#     'url': 'https://fr.slideshare.net/slideshow/yummy-magazine-n17/50207861',
#     'userLogin': 'YummyMagazine',
#     'userName': 'YummyMagazine',
#     'viewCount': 3453},
#    {'algorithmId': '3',
#     'displayTitle': 'Gastronomie france ',
#     'isSavedByCurrentUser': False,
#     'pageCount': 17,
#     'score': 0.3817,
#     'slideshowId': '72982727',
#     'sourceName': 'cm_text',
#     'strippedTitle': 'gastronomie-france',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/gastronomiefrance21-170309113034-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'Gastonomie française',
#     'tags': ['gastronomie', 'france'],
#     'url': 'https://fr.slideshare.net/slideshow/gastronomie-france/72982727',
#     'userLogin': 'clamuraller',
#     'userName': 'clamuraller',
#     'viewCount': 585},
#    {'algorithmId': '3',
#     'displayTitle': 'Hellouin magazine printemps 2017 ',
#     'isSavedByCurrentUser': False,
#     'pageCount': 24,
#     'score': 0.3811,
#     'slideshowId': '73249969',
#     'sourceName': 'cm_text',
#     'strippedTitle': 'hellouin-magazine-printemps-2017',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/hellouinmagazineprintemps2017web-170317112226-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': "Hellouin Magazine, l'art de vivre dans un esprit campagne chic; le produit du terroir l'asperge, à la découverte des origines de la soupe, l'artiste du mois un savant mélange de coquillages et d'aqurelle, au jardin au printemps des poules en céramique",
#     'tags': ['cuisine', 'magazine art de vivre', 'asperge'],
#     'url': 'https://fr.slideshare.net/MonEpicerieFine/hellouin-magazine-printemps-2017',
#     'userLogin': 'MonEpicerieFine',
#     'userName': 'Mon Epicerie Fine de Terroir',
#     'viewCount': 136},
#    {'algorithmId': '3',
#     'displayTitle': 'la Gastronomie',
#     'isSavedByCurrentUser': False,
#     'pageCount': 99,
#     'score': 0.3803,
#     'slideshowId': '47599491',
#     'sourceName': 'cm_text',
#     'strippedTitle': 'la-gastronomie-47599491',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/gastronomie-150430042326-conversion-gate02-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'Gastronomie francais',
#     'tags': [],
#     'url': 'https://fr.slideshare.net/slideshow/la-gastronomie-47599491/47599491',
#     'userLogin': 'urazzaya',
#     'userName': 'urazzaya',
#     'viewCount': 716},
#    {'algorithmId': '3',
#     'displayTitle': 'Inauguration in paris restaurant nosso',
#     'isSavedByCurrentUser': False,
#     'pageCount': 4,
#     'score': 0.3796,
#     'slideshowId': '248410455',
#     'sourceName': 'cm_text',
#     'strippedTitle': 'inauguration-in-paris-restaurant-nosso',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/inaugurationinparisrestaurantnosso-210521123927-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'Inauguration event 2021 Paris France',
#     'tags': [],
#     'url': 'https://fr.slideshare.net/slideshow/inauguration-in-paris-restaurant-nosso/248410455',
#     'userLogin': 'RajeshTaneja8',
#     'userName': 'Chaîne des Rôtisseurs Bailliage National du Vietnam ',
#     'viewCount': 51},
#    {'algorithmId': '3',
#     'displayTitle': 'La france a 360 gastronomie',
#     'isSavedByCurrentUser': False,
#     'pageCount': 9,
#     'score': 0.3753,
#     'slideshowId': '34471354',
#     'sourceName': 'cm_text',
#     'strippedTitle': 'la-france-a-360-gastronomie-34471354',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lafrancea360gastronomie-140509024104-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': '',
#     'tags': [],
#     'url': 'https://fr.slideshare.net/slideshow/la-france-a-360-gastronomie-34471354/34471354',
#     'userLogin': 'LaurenceFreudenreich',
#     'userName': 'LaurenceFreudenreich',
#     'viewCount': 525},
#    {'algorithmId': '3',
#     'displayTitle': 'французская кухня',
#     'isSavedByCurrentUser': False,
#     'pageCount': 28,
#     'score': 0.3708,
#     'slideshowId': '39745885',
#     'sourceName': 'cm_text',
#     'strippedTitle': 'ss-39745885',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/random-141001060250-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'французская кухня',
#     'tags': [],
#     'url': 'https://fr.slideshare.net/slideshow/ss-39745885/39745885',
#     'userLogin': 'turova1858',
#     'userName': 'turova1858',
#     'viewCount': 519},
#    {'algorithmId': '3',
#     'displayTitle': 'La France a 360  Cours 4 Gastronomie',
#     'isSavedByCurrentUser': False,
#     'pageCount': 9,
#     'score': 0.3679,
#     'slideshowId': '26859373',
#     'sourceName': 'cm_text',
#     'strippedTitle': 'la-france-a-360-gastronomie',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lafrancea360cours4-131004062145-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'La gastronomie française',
#     'tags': [],
#     'url': 'https://fr.slideshare.net/slideshow/la-france-a-360-gastronomie/26859373',
#     'userLogin': 'LaurenceFreudenreich',
#     'userName': 'LaurenceFreudenreich',
#     'viewCount': 1055},
#    {'algorithmId': '3',
#     'displayTitle': 'Proiect _la_cuisine_francaise.Proiect despre bucătăria franțuzeascăppt',
#     'isSavedByCurrentUser': False,
#     'pageCount': 24,
#     'score': 0.3677,
#     'slideshowId': '270079663',
#     'sourceName': 'cm_text',
#     'strippedTitle': 'proiect-_la_cuisine_francaise-proiect-despre-bucataria-fran-uzeascappt',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/01lacuisinefrancaise-240705112320-930e7cdd-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'bucătărie franțuzească\nla cuisine francaise',
#     'tags': ['langue française'],
#     'url': 'https://fr.slideshare.net/slideshow/proiect-_la_cuisine_francaise-proiect-despre-bucataria-fran-uzeascappt/270079663',
#     'userLogin': 'otiliaungureanu27',
#     'userName': 'otiliaungureanu27',
#     'viewCount': 2},
#    {'algorithmId': '3',
#     'displayTitle': 'Présentations 4 cours 2007-2008',
#     'isSavedByCurrentUser': False,
#     'pageCount': 18,
#     'score': 0.3675,
#     'slideshowId': '571952',
#     'sourceName': 'cm_text',
#     'strippedTitle': 'prsentations-4-cours-20072008-presentation',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lagastronomie-lpn-1219865399318401-9-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': '',
#     'tags': [],
#     'url': 'https://fr.slideshare.net/slideshow/prsentations-4-cours-20072008-presentation/571952',
#     'userLogin': 'laprofdefran',
#     'userName': 'laprofdefran',
#     'viewCount': 697},
#    {'algorithmId': '3',
#     'displayTitle': 'Ma Cuisine, Votre Cuisine',
#     'isSavedByCurrentUser': False,
#     'pageCount': 23,
#     'score': 0.3662,
#     'slideshowId': '1948629',
#     'sourceName': 'cm_text',
#     'strippedTitle': 'ma-cuisine-votre-cuisine2',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/macuisinevotrecuisine2-12520062250798-phpapp03-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': '',
#     'tags': [],
#     'url': 'https://fr.slideshare.net/pourou/ma-cuisine-votre-cuisine2',
#     'userLogin': 'pourou',
#     'userName': 'pourou',
#     'viewCount': 1003},
#    {'algorithmId': '3',
#     'displayTitle': 'La gastronomie française',
#     'isSavedByCurrentUser': False,
#     'pageCount': 6,
#     'score': 0.3644,
#     'slideshowId': '57736822',
#     'sourceName': 'cm_text',
#     'strippedTitle': 'la-gastronomie-franaise-57736822',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lagastronomiefranaise-160201145456-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'Plats typiques',
#     'tags': [],
#     'url': 'https://fr.slideshare.net/slideshow/la-gastronomie-franaise-57736822/57736822',
#     'userLogin': 'gonzalezotero',
#     'userName': 'gonzalezotero',
#     'viewCount': 1661},
#    {'algorithmId': '3',
#     'displayTitle': '6 la cuisine',
#     'isSavedByCurrentUser': False,
#     'pageCount': 16,
#     'score': 0.3614,
#     'slideshowId': '13105736',
#     'sourceName': 'cm_text',
#     'strippedTitle': '6-la-cuisine',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/6lacuisine-120528100347-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'ss',
#     'tags': [],
#     'url': 'https://fr.slideshare.net/slideshow/6-la-cuisine/13105736',
#     'userLogin': 'ndyazman',
#     'userName': 'ndyazman',
#     'viewCount': 516},
#    {'algorithmId': '3',
#     'displayTitle': 'Carte gb 1.05.17',
#     'isSavedByCurrentUser': False,
#     'pageCount': 6,
#     'score': 0.3562,
#     'slideshowId': '75542457',
#     'sourceName': 'cm_text',
#     'strippedTitle': 'carte-gb-10517',
#     'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/cartegb1-170430131639-thumbnail.jpg?width=600&height=600&fit=bounds',
#     'description': 'Carte du restaurant "La Gouensière"',
#     'tags': ['saint malo cancale mont saint michel michelin star'],
#     'url': 'https://fr.slideshare.net/slideshow/carte-gb-10517/75542457',
#     'userLogin': 'maisontirelguerin',
#     'userName': 'Maison Tirel Guerin',
#     'viewCount': 240}],
#   'moreFromUser': [],
#   'featured': None,
#   'latest': []},
#  'secretUrl': 'gQmo6wGfATUguS',
#  'shouldShowAds': True,
#  'slides': {'host': 'https://image.slidesharecdn.com',
#   'title': 'Cuisine-Francais',
#   'imageLocation': 'repasfranais-150329050530-conversion-gate01',
#   'imageSizes': [{'quality': 85, 'width': 320, 'format': 'jpg'},
#    {'quality': 85, 'width': 638, 'format': 'jpg'},
#    {'quality': 75, 'width': 2048, 'format': 'webp'}]},
#  'strippedTitle': 'repas-franais-46412448',
#  'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/repasfranais-150329050530-conversion-gate01-thumbnail.jpg?width=640&height=640&fit=bounds',
#  'title': 'Cuisine Français',
#  'totalSlides': 21,
#  'transcript': ['CUISINE FRANÇAISE\nNuriyya Guliyeva\n ',
#   "CUISINE FRANÇAISE EST MONDIALEMENT\nCONNU POUR SA FINESSE ET LA SAVEUR.\nLA NOURRITURE EST UNE PARTIE TRÈS\nIMPORTANTE DE LA VIE EN FRANCE, CE\nQUI EN FAIT ÉGALEMENT UN ÉLÉMENT\nTRÈS IMPORTANT DE LA CULTURE\nFRANÇAISE. ALORS QUE LES\nBRITANNIQUES SONT CONNUS POUR LEUR\nTHÉ L'APRÈS-MIDI ET LES AMÉRICAINS\nSONT CONNUS POUR LEURS BUFFETS SANS\nFOND, LES FRANÇAIS SONT CONNUS POUR,\nREPAS LONGUES PERSISTANTES QUI\nCOMPORTENT PLUSIEURS COURS. CETTE\nCULTURE ALIMENTAIRE EST UNE PARTIE\nINTÉGRANTE DE LA VIE QUOTIDIENNE EN\nFRANCE.\n ",
#   "LA CUISINE FRANÇAISE ET LES PLATS NATIONAUX FRANÇAIS ONT DÉVELOPPÉ\nDES SIÈCLES DE CHANGEMENT SOCIAL ET POLITIQUE. CERTAINS PLATS SONT\nCONSIDÉRÉS COMME UNIVERSELLEMENT ACCEPTÉES COMME FAISANT PARTIE\nDES ALIMENTS NATIONAUX FRANÇAIS, TANDIS QUE D'AUTRES SE INSCRIVENT\nDANS UNE CUISINE RÉGIONALE UNIQUE.\nPAINS, FROMAGES, VINS ET SONT UNE PARTIE IMPORTANTE DE LA CUISINE\nFRANÇAISE, JOUANT DIFFÉRENTS RÔLES RÉGIONAL ET NATIONAL, AVEC DE\nNOMBREUSES VARIANTES ET DES LOIS.\n ",
#   'ALORS QUE LES REPAS EN FRANCE ONT TENDANCE À ÊTRE LONG, LE\nPETIT DÉJEUNER PEUT ÊTRE UNE AFFAIRE ASSEZ RAPIDE. TANDIS QUE LE\nDÎNER ET LE DÉJEUNER PEUVENT SEMBLER LONGS REPAS AVEC UNE\nSURABONDANCE DE NOURRITURE, PETIT DÉJEUNER PEUT SEMBLER\nPARTICULIÈREMENT LIMITÉ SELON LES NORMES AMÉRICAINES.\n ',
#   'POT-AU-FEU EST UN RAGOÛT DE BOEUF FRANÇAIS. QUI EST "LA QUINTESSENCE\nDE LA CUISINE FRANÇAISE ET EST LE PLAT DE LA FAMILLE LES PLUS CÉLÈBRES EN\nFRANCE. IL HONORE LES TABLEAUX À LA FOIS LES RICHES ET LES PAUVRES. IL YA DES\nVARIATIONS QUE LES COUPES DE BOEUF, LÉGUMES ET ÉPICES IMPLIQUÉS, MAIS UN\nPOT TYPIQUE CONTIENT BOEUF AU-FEU OU SAUCISSES, GÉNÉRALEMENT UNE SORTE\nDE VIANDE CARTILAGINEUSE, COMME LA QUEUE DE BŒUF ET MARROWBONE,\nLÉGUMES-RACINES ET LE BOUQUET GARNI.\n ',
#   "BLANQUETTE DE VEAU EST UN RAGOÛT OU UN RAGOÛT FRANÇAIS DANS LEQUEL\nVEAU ET LÉGUMES SONT CUITS DANS UNE SAUCE DE PIÈCES DE BOUILLON, LA\nFARINE, LE BEURRE, LA CRÈME, ET / OU LE JAUNE D'OEUF. CHAMPIGNONS, RIZ, PÂTES\nET POMMES DE TERRE ACCOMPAGNENT GÉNÉRALEMENT CE PLAT, QUI EST SERVI\nCHAUD.\nCOQ AU VIN EST UN PLAT NATIONAL FRANÇAIS, UNE BRAISE DE POULET CUIT AVEC DU\nVIN, LARDONS, LES CHAMPIGNONS ET L'AIL EN OPTION.\n ",
#   "RATATOUILLE EST UN RAGOÛT DE LÉGUMES AVEC L'HUILE D'OLIVE,\nAUBERGINE, COURGETTE, POIVRON, TOMATE, OIGNON ET L'AIL.\n ",
#   'FOIE GRAS EST FAITE DU FOIE\nD\'UN CANARD OU D\'OIE QUI A\nÉTÉ SPÉCIALEMENT\nENGRAISSÉ PAR GAVAGE. LE\nFOIE GRAS EST UNE\nDÉLICATESSE POPULAIRE ET\nBIEN CONNUE DANS LA\nCUISINE FRANÇAISE. FOIE\nGRAS EST VENDU ENTIER OU\nEST PRÉPARÉ EN MOUSSE,\nPARFAIT, OU PÂTÉ, ET PEUT\nÉGALEMENT ÊTRE SERVI EN\nACCOMPAGNEMENT D\'UN\nAUTRE ALIMENT, COMME LE\nSTEAK. LA LOI FRANÇAISE\nSTIPULE QUE «FOIE GRAS FAIT\nPARTIE DU PATRIMOINE\nCULTUREL ET\nGASTRONOMIQUE PROTÉGÉ EN\nFRANCE."\n ',
#   "CASSOULET EST UN RICHE, CUIT LENTEMENT RAGOÛT DE HARICOTS OU UNE\nCOCOTTE ORIGINAIRE DU SUD DE LA FRANCE CONTENANT DE PORC,\nSAUCISSES, D'OIE OU DE CANARD ET ET HARICOTS BLANCS.\n ",
#   'QUICHE LORRAINE EST UN PLAT NATIONAL\nFRANÇAIS, UNE TARTE OUVERTE FAIT AVEC\nDES OEUFS ET DU LAIT OU DE LA CRÈME,\nDU BACON ET DE FROMAGE DANS UNE\nCROÛTE DE PÂTE.\n ',
#   "SOUPES TRADITIONNELLES FRANÇAISES\nSoupe à la citrouille\nDans le centre de la France, soupe\nau potiron est un favori. À\nl'automne, lorsque les citrouilles et\nles pommes de terre sont récoltées,\ncette soupe est présenté sur de\nnombreuses tables traditionnelles.\nLes principaux ingrédients sont\nmélangés avec de la crème et garni\nde croûtons ou servi avec une\nbaguette fraîchement cuit.\nSoupe à l'oignon\nCe est une soupe\ntraditionnelle française\npréparée d'oignons et de\nbouillon de bœuf,\ngénéralement servi avec\ncroûtons et de fromage sur\nle dessus.\n ",
#   "FROMAGES FRANÇAIS PEUVENT PRÉPARER UN REPAS SUR LEUR PROPRE,\nCERTAINEMENT LORSQUE JUMELÉ AVEC PAIN FRAIS! CHEESE A UNE LONGUE\nHISTOIRE EN FRANCE D'ÊTRE SERVI APRÈS UN REPAS, AVANT LE DESSERT. LES\nFROMAGES SONT RÉGIONALE EN FRANCE, COMME LE VIN. ALORS QUE CERTAINS\nFROMAGES SE CHEVAUCHENT ENTRE LES RÉGIONS, IL YA DES FROMAGES\nPARTICULIERS QUI VIENNENT DE CERTAINES RÉGIONS. EN TOUT BON SUPERMARCHÉ\nSI VOUS POUVEZ TROUVER TOUS LES TYPES DE FROMAGES, DE CHÈVRE ET DE LAIT DE\nBREBIS FROMAGES, PLUS TRADITIONNELS, DUR, PERSONNES ÂGÉES, LES FROMAGES.\n ",
#   'CRÊPES SONT CONSIDÉRÉS COMME UN\nALIMENT NATIONAL FRANÇAIS. LES CRÊPES\nMINCES SOUPLES SONT SERVIS AVEC UNE\nVARIÉTÉ DE GARNITURES, DE LA PLUS SIMPLE\nAVEC SEULEMENT SUCRE CRÊPES SUZETTE\nFLAMBÉES OU ÉLABORER GARNITURES SALÉES,\nSERVIS POUR LE PETIT DÉJEUNER, DÉJEUNER,\nDÎNER OU QUE DES DESSERTS.\n ',
#   'DESSERTS NATIONAUX FRANÇAIS\nÉclairsMousse au Chocolat\n ',
#   'MILLE-FEUILLES ET TARTE TATIN\n ',
#   'AVANT REPAS FRANÇAIS GENS ONT TRADITIONNELLEMENT UNE BOISSON\nALCOOLISÉE LA LUMIÈRE APPELÉ UN "APÉRITIF". UN APÉRITIF POPULAIRE,\nEN PARTICULIER DANS LE SUD DE LA FRANCE, EST LE «PASTIS», UNE\nBOISSON FONT DE L\'ANIS VERT.\nPASTIS EST UN ESPRIT D\'ANIS ET APÉRITIF DE LA FRANCE, CONTENANT\nTYPIQUEMENT SUCRE ET D\'ALCOOL, BIEN QUE LES VARIÉTÉS SANS ALCOOL\nEXISTENT.\n ',
#   'PETIT DÉJEUNER FRANÇAIS\nPETIT DÉJEUNER EN FRANCE EST GÉNÉRALEMENT UNE AFFAIRE DE\nLUMIÈRE, AVEC LA BOISSON (GÉNÉRALEMENT CAFÉ) ÉTANT TOUT AUSSI\nIMPORTANT QUE LA NOURRITURE. CERTAINS CHOIX DE PETIT DÉJEUNER\nTYPIQUEMENT FRANÇAIS:\n\uf0a2 Tartines, qui est pain grillé avec de\nla confiture, est un petit déjeuner\ntypiquement français aimait pour\nsa simplicité et la saveur sucrée\nqui va bien avec coffee.Croissants\nsont un petit week-end commun.\n ',
#   '"PAIN AU CHOCOLAT" EST UN PETIT LUXE BIEN-AIMÉ EN FRANCE,\nNOTAMMENT PAR LES ENFANTS. LE WEEK-END EN PARTICULIER, DES\nCROISSANTS AU CHOCOLAT (MÊME SE ILS NE SONT PAS LA MÊME FORME\nQUE D\'UN CROISSANT TRADITIONNELLE) PEUVENT ÊTRE ACHETÉS POUR\nLES ENFANTS.\n\uf0a2 Beaucoup de Français vont\natteindre pour le café avant de\nla plaque de petit-déjeuner.\nBien que le type de café par\ndéfaut en France est expresso,\nil est courant de demander un\ncafé au lait au petit déjeuner.\nCe café est servi dans un grand\nbol ou une tasse ronde, et a\nbeaucoup de lait ajouté.\nD\'autres options sont le thé ou\nle chocolat chaud.\n ',
#   'VOUS TROUVEREZ LES RÉPONSES LES PLUS VARIÉES À LA QUESTION: «QUE DOIS\nFRANÇAIS MANGENT ?," À MIDI EN FRANCE. ALORS QUE CERTAINES PERSONNES\nFRANÇAISES QUITTENT LE TRAVAIL PENDANT DEUX HEURES ET MANGER UN\nREPAS DE PLUSIEURS PLATS SERVI AVEC DU VIN, LES AUTRES FRANÇAIS PRENDRE\nUN SANDWICH À PARTIR D\'UN VENDEUR DE RUE.\ndéjeuner au restaurant déjeuner à la maison\n ',
#   "DÎNER FRANÇAIS\nDÎNERS EN FRANCE PEUVENT VARIER EN FONCTION DU JOUR DE LA SEMAINE ET\nLA TAILLE D'UN DÉJEUNER DE REPAS ÉTAIT. COUPLES QUI RENTRENT CHEZ EUX\nPOUR UN DÉJEUNER DÉCADENT ONT SOUVENT UN DÎNER SIMPLE, ALORS QUE\nCEUX QUI MANGENT UN SANDWICH À MIDI POURRAIT MANGER UN REPAS PLUS\nGRANDE. LORS D'OCCASIONS SPÉCIALES, DÎNERS DEVIENNENT PLUS, DISPOSENT\nPLUS DE COURS (EN PARTICULIER LE PLATEAU DE FROMAGES), ET LA TABLE EST\nFIXÉ AVEC DES DRAPS ET DES PLAQUES DE FANTAISIE.\n ",
#   "MERCI POUR VOTRE TEMPS ET\nD'ATTENTION!\n "],
#  'type': 'presentation',
#  'facebookShareUrl': 'https://facebook.com/sharer.php?u=https%3A%2F%2Ffr.slideshare.net%2Fslideshow%2Frepas-franais-46412448%2F46412448&t=Cuisine+Fran%C3%A7ais',
#  'twitterShareUrl': 'https://twitter.com/intent/tweet?via=SlideShare&text=Cuisine+Fran%C3%A7ais+https%3A%2F%2Ffr.slideshare.net%2Fslideshow%2Frepas-franais-46412448%2F46412448',
#  'linkedinShareUrl': 'https://www.linkedin.com/cws/share?url=https%3A%2F%2Ffr.slideshare.net%2Fslideshow%2Frepas-franais-46412448%2F46412448&trk=SLIDESHARE',
#  'smsShareUrl': 'sms:?body=Check out this SlideShare : https://fr.slideshare.net/slideshow/repas-franais-46412448/46412448',
#  'emailShareUrl': 'mailto:?subject=Check out this SlideShare presentation&body=https://fr.slideshare.net/slideshow/repas-franais-46412448/46412448',
#  'slideDimensions': {'height': 540, 'width': 720},
#  'topReadSlides': [{'slideIndex': 2, 'ranking': 2},
#   {'slideIndex': 3, 'ranking': 3},
#   {'slideIndex': 1, 'ranking': 1}],
#  'user': {'id': '73422186',
#   'isFollowing': False,
#   'login': 'nuriagulieva',
#   'name': 'Nuriyya Guliyeva',
#   'occupation': None,
#   'organization': None,
#   'photo': 'https://public.slidesharecdn.com/v2/images/profile-picture.png',
#   'photoExists': False,
#   'shortName': 'Nuriyya Guliyeva'},
#  'views': 1131}

# %% [markdown]
# ## Scraping

# %% [markdown]
# ### Get urls of slideshows

# %% [markdown]
# Set the number of pages (1 page = 18 slideshows)

# %%
#page_i is the url format of the content search page in French on slideshare
#the first page is page_i.format(1), the second page is page_2.format(2) etc...
#nb pages is the number of the last content search page that we scrap.
page_i = "https://fr.slideshare.net/search?searchfrom=header&q=fran%C3%A7ais&page={}"
nb_pages = 30
urls = []

# %% [markdown]
# Execute this to scrap urls of slideshows

# %%
#Execution of the scraper
for i in range(1,nb_pages+1) :
    urls.extend(extract_urls_from_search(page_i.format(i)))

# %%
with open("urls.csv", "w", newline="") as f:
    for url in urls : f.write(f"{url}\n")

# %% [markdown]
# If you have already scraped urls you can get them with :

# %%
urls = []
with open("urls.csv", "r") as f :
    for url in f.readlines() : urls.append(url)

# %% [markdown]
# If you begin the scraping execute this cell and execute the scraping cell:

# %%
last_slideshow = -1

# %% [markdown]
# If you want to resume after a break of the loop, execute this cell and relunch the scraping cell

# %%
with open("last_slideshow.txt") as f : last_slideshow = int(f.read())

# %% [markdown]
# Scraping cell :

# %%
#Scraping cell
for j in tqdm(range(last_slideshow+1, len(urls))) :
    try :
        scrap(urls[j])
        sleep(3)
    except KeyError as e : print(f"KeyError catched : {e}")
    except requests.exceptions.ConnectionError as e : print(f"ConnectionError catched : {e}")
    except requests.exceptions.HTTPError as e : print(f"HTTPError catched : {e}")
    last_slideshow+=1
    with open("last_slideshow.txt", "w") as f : f.write(str(last_slideshow))

# %% [markdown]
# ## Post Processing

# %% [markdown]
# Before the Q/A generation, please run this cell :

# %%
#Verif integrity
listdir = os.listdir(DATA_PATH)
for dir in listdir : 
    meta_data_path = f"{DATA_PATH}/{dir}/{dir}.json"
    if not os.path.exists(meta_data_path) :
        print(f"Can't find meta-data for {dir}")
        shutil.rmtree(f"{DATA_PATH}/{dir}")
    else :
        with open(meta_data_path, "r") as f:
            meta_data = json.load(f)
        if type(meta_data["id"]) != str : print(f"{dir} : id type error")
        if type(meta_data["presentation_url"]) != str : print(f"{dir}: presentation_url type error")
        if type(meta_data["title"]) != str : print(f"{dir} : title type error")
        if type(meta_data["author"]) != str: print(f"{dir} : author type error")
        if type(meta_data["date"]) != str : print(f"{dir} : date type error")
        if type(meta_data["len"]) != int : print(f"{dir} : len type error")
        if type(meta_data["description"]) != str : print(f"{dir} : description type error")
        if type(meta_data["lang"]) != str : print(f"{dir} :lang  type error")
        if type(meta_data["dim"]) != dict : print(f"{dir} : dim type error")
        if type(meta_data["like"]) != int : print(f"{dir} : like type error")
        if type(meta_data["view"]) != int : print(f"{dir} : view type error")
        if type(meta_data["transcript"]) != list : print(f"{dir} : transcript type error")
        if type(meta_data["mostRead"]) != list : print(f"{dir} : mostRead type error")

# %% [markdown]
# If the previous cell returns nothing, you can go to generate_qa.ipynb
