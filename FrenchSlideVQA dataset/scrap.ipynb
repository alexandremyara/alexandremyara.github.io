# %% [markdown]
# ## Import

# %%
import json
import requests
from bs4 import BeautifulSoup
import os
from selenium import webdriver
from time import sleep
from PIL import Image
from glob import glob
import shutil

# %% [markdown]
# ## Scraper

# %%
def load_html(url:str, static=True) :
    """
    Load a BeautifulSoup instance over an HTML page.
    If static=False, we use Selenium to load the page.
    If static=True, we use requests to load the page.
    Input :
    url: str, url of the page
    static: bool
    """

    if static :
        response = requests.get(url)
        return BeautifulSoup(response.content, "html.parser")
    else :
        driver = webdriver.Firefox()
        driver.get(url)
        sleep(5)
        html = driver.page_source
        soup = BeautifulSoup(html, "html.parser")
        driver.quit()
        return soup

# %%
def extract_urls_from_search(search_url) :
    urls=[]
    soup = load_html(search_url, False)
    for tag in soup.find_all("a", href=True) :
        if "from_search" in tag["href"] : urls.append(tag["href"])
    return urls

# %%
def extract_most_read(slideshow: dict) -> list :
    """
    Construct a one-hot vector of length nb_slides. Put a 1 at the index of slides most read.
    Inputs :
    slideshow: dict, metadata of the slideshow (extracted with BeautifulSoup)
    Ouputs :
    isMostRead: list, one-hot vector of nb_slides 
    """
    nb_slides = slideshow["totalSlides"]
    indexMostRead = [list(slide.items())[0][1] for slide in slideshow["topReadSlides"]]
    isMostRead = [1 if k in indexMostRead else 0 for k in range(nb_slides)]
    return isMostRead

# %%
def scrap(url:str) :
    """
    The scrap function slides from SlideShare.net and then creates a folder which contains all slides in jpg format.
    Input :
    url : a str-like, contains the url of the download page of the slides
    """
    #html request
    soup = load_html(url)

    #The script tag with id "__NETX_DATA__" contains with a json format some meta informations.
    data = json.loads(soup.select_one("#__NEXT_DATA__").text)
    slideshow =  data["props"]["pageProps"]["slideshow"]
    meta_data = { "id": slideshow["id"],
                  "presentation_url": slideshow["canonicalUrl"],
                  "title": slideshow["title"],
                  "author": slideshow["username"],
                  "date": slideshow["createdAt"][:10], #AAAA-MM-JJ
                  "len": slideshow["totalSlides"],
                  "description": slideshow["description"],
                  "lang": slideshow["language"],
                  "dim": slideshow["slideDimensions"],
                  "like": slideshow["likes"],
                  "view": slideshow["views"],
                  "transcript": slideshow["transcript"],
                  "mostRead": extract_most_read(slideshow),
                  }
    #img_urls
    slides = slideshow["slides"]
    sizes = slides["imageSizes"][1]
    img_url = f"{slides['host']}/{slides['imageLocation']}/{sizes['quality']}/{slideshow['title']}-" + "{}" + f"-{sizes['width']}.{sizes['format']}"

    #folder creation
    folder_name = str(slideshow["id"])
                                      
    if os.path.exists("data/"+folder_name) : shutil.rmtree("data/"+folder_name)
    os.mkdir("data/"+folder_name)
    
    #For each image
    for i in range(slideshow["totalSlides"]):
        response = requests.get(img_url.format(i+1))
        sleep(5)
        with open(f"data/{folder_name}/slide_{i}.jpg", "wb") as f :
            f.write(response.content)
            
    with open(f"data/{folder_name}/{folder_name.lower()}.json", "w") as f :
        json.dump(meta_data,f)

# %% [markdown]
# ## Test Scraper

# %%
url = "https://fr.slideshare.net/slideshow/repas-franais-46412448/46412448?from_search=0"
soup = load_html(url)
json.loads(soup.select_one("#__NEXT_DATA__").text)
# Out:
# {'props': {'pageProps': {'name': 'slideshow',
#    'edgeTestAssignments': [{'name': 'example', 'variant': 'B'},
#     {'name': 'gallery_view', 'variant': 'A'},
#     {'name': 'mobile_cleanup', 'variant': 'B'},
#     {'name': 'nextjs_profile', 'variant': 'A'},
#     {'name': 'reading_modes', 'variant': 'A'},
#     {'name': 'recs_placement', 'variant': 'A'},
#     {'name': 'recs_placement_v2', 'variant': 'B'}],
#    'layout': {'currentUser': None,
#     'fullPath': 'https://fr.slideshare.net/slideshow/repas-franais-46412448/46412448?from_search=0',
#     'osanoId': '079b27eb-bb3f-48dd-9bd9-3feb8aec3c38',
#     'featureFlags': [{'name': 'disable_facebook', 'enabled': True},
#      {'name': 'document_interstitials_flag', 'enabled': True},
#      {'name': 'recommendation_impression_tracking', 'enabled': True},
#      {'name': 'search_results_tracking', 'enabled': True},
#      {'name': 'view_restriction_without_subscription_after_five',
#       'enabled': True},
#      {'name': 'disable_lazy_hydration', 'enabled': False}]},
#    'countryCodeFromFastly': 'FR',
#    'slideshow': {'username': 'nuriagulieva',
#     'id': '46412448',
#     'allowDownloads': True,
#     'allowDownloadOriginalFile': True,
#     'allowEmbeds': True,
#     'categories': [{'id': '29', 'name': 'Alimentation', 'url': 'food'}],
#     'canonicalUrl': 'https://fr.slideshare.net/slideshow/repas-franais-46412448/46412448',
#     'createdAt': '2015-03-29 05:05:30 UTC',
#     'description': 'Repas Français.',
#     'downloadKey': '8703f5a6fc289d34e0013d3d7dd616716ae6ee086966beb9c6b3657a64bbb94e',
#     'editorsNotes': [],
#     'extension': 'pptx',
#     'genaiTest': 'control',
#     'genaiDescriptionCreatedAt': None,
#     'iframeEmbed': {'url': 'https://www.slideshare.net/slideshow/embed_code/key/gQmo6wGfATUguS',
#      'height': 486,
#      'width': 597},
#     'isIndexable': True,
#     'isPrivate': False,
#     'isViewable': True,
#     'language': 'fr',
#     'likes': 2,
#     'isLikedByCurrentUser': False,
#     'recommendationsByLocation': {'rightRail': [{'algorithmId': '5',
#        'displayTitle': 'Gastronomie',
#        'isSavedByCurrentUser': False,
#        'pageCount': 14,
#        'score': 0.74873,
#        'slideshowId': '268439',
#        'sourceName': 'cm_interact',
#        'strippedTitle': 'gastronomie',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/gastronomie-1203183040327270-2-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': '',
#        'tags': [],
#        'url': 'https://fr.slideshare.net/MariolaMoreno/gastronomie',
#        'userLogin': 'MariolaMoreno',
#        'userName': 'MariolaMoreno',
#        'viewCount': 5596},
#       {'algorithmId': '5',
#        'displayTitle': 'La Gastronomie En France',
#        'isSavedByCurrentUser': False,
#        'pageCount': 68,
#        'score': 0.726242,
#        'slideshowId': '28639045',
#        'sourceName': 'cm_interact',
#        'strippedTitle': 'la-gastronomie-en-france',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lagastronomieenfranceforafrances-131126084457-phpapp01-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'Presentación de la gastronomía de Francia en general.\r\nIES Foramontanos - 4ºESO',
#        'tags': [],
#        'url': 'https://fr.slideshare.net/slideshow/la-gastronomie-en-france/28639045',
#        'userLogin': 'FrancesForamontanos',
#        'userName': 'FrancesForamontanos',
#        'viewCount': 19324},
#       {'algorithmId': '5',
#        'displayTitle': 'La gastronomie francaise',
#        'isSavedByCurrentUser': False,
#        'pageCount': 23,
#        'score': 0.724776,
#        'slideshowId': '61996999',
#        'sourceName': 'cm_interact',
#        'strippedTitle': 'la-gastronomie-francaise',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/projetfrengjishtejeblertabasha-160513184904-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'La gastronomie francaise\r\n',
#        'tags': [],
#        'url': 'https://fr.slideshare.net/koralda/la-gastronomie-francaise',
#        'userLogin': 'koralda',
#        'userName': 'koralda',
#        'viewCount': 5402},
#       {'algorithmId': '5',
#        'displayTitle': 'FLE - Aliments - Repas',
#        'isSavedByCurrentUser': False,
#        'pageCount': 7,
#        'score': 0.663082,
#        'slideshowId': '13951717',
#        'sourceName': 'cm_interact',
#        'strippedTitle': 'screen-alimentsrepas',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/screen-aliments-repas-120812163221-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'French vocabulary for the food.',
#        'tags': ['learn french', 'parismonterrey.com', 'aliments'],
#        'url': 'https://fr.slideshare.net/slideshow/screen-alimentsrepas/13951717',
#        'userLogin': 'ParisMonterrey',
#        'userName': 'Nathalie Maguérès',
#        'viewCount': 5054},
#       {'algorithmId': '5',
#        'displayTitle': 'Gastronomie De France',
#        'isSavedByCurrentUser': False,
#        'pageCount': 29,
#        'score': 0.648841,
#        'slideshowId': '427107',
#        'sourceName': 'cm_interact',
#        'strippedTitle': 'gastronomie-de-france',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/gastronimie-de-france-1211728489285887-8-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': '',
#        'tags': ['civilisation', 'civilisation'],
#        'url': 'https://fr.slideshare.net/slideshow/gastronomie-de-france/427107',
#        'userLogin': 'MariolaMoreno',
#        'userName': 'MariolaMoreno',
#        'viewCount': 117786},
#       {'algorithmId': '5',
#        'displayTitle': 'La cuisine francaise',
#        'isSavedByCurrentUser': False,
#        'pageCount': 12,
#        'score': 0.635374,
#        'slideshowId': '15581308',
#        'sourceName': 'cm_interact',
#        'strippedTitle': 'la-cuisine-francaise',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lacuisinefrancaise-121210205814-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': '',
#        'tags': [],
#        'url': 'https://fr.slideshare.net/slideshow/la-cuisine-francaise/15581308',
#        'userLogin': 'sitnikova26',
#        'userName': 'sitnikova26',
#        'viewCount': 3118},
#       {'algorithmId': '5',
#        'displayTitle': 'Vocabulaire: La Cuisine ',
#        'isSavedByCurrentUser': False,
#        'pageCount': 104,
#        'score': 0.625346,
#        'slideshowId': '32860252',
#        'sourceName': 'cm_interact',
#        'strippedTitle': 'vocabulaire-la-cuisine',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/1lacuisinepowerpointlikespanish2-140328120548-phpapp01-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'French vocabulary for foods ',
#        'tags': [],
#        'url': 'https://fr.slideshare.net/slideshow/vocabulaire-la-cuisine/32860252',
#        'userLogin': 'madameburley',
#        'userName': 'Ma Dame Burley',
#        'viewCount': 3325},
#       {'algorithmId': '5',
#        'displayTitle': 'Les Pays Francophones 2',
#        'isSavedByCurrentUser': False,
#        'pageCount': 7,
#        'score': 0.623454,
#        'slideshowId': '2451435',
#        'sourceName': 'cm_interact',
#        'strippedTitle': 'les-pays-francophones-2',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lespaysfrancophones2-091108121513-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': '',
#        'tags': [],
#        'url': 'https://fr.slideshare.net/slideshow/les-pays-francophones-2/2451435',
#        'userLogin': 'silviagala29',
#        'userName': 'Silvia GaLa',
#        'viewCount': 37602}],
#      'whatsHot': [{'algorithmId': '5',
#        'displayTitle': 'Les sports',
#        'isSavedByCurrentUser': False,
#        'pageCount': 51,
#        'score': 0.610351,
#        'slideshowId': '31771931',
#        'sourceName': 'cm_interact',
#        'strippedTitle': 'les-sports-31771931',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lessports-140228114039-phpapp01-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': '',
#        'tags': [],
#        'url': 'https://fr.slideshare.net/slideshow/les-sports-31771931/31771931',
#        'userLogin': 'departamentofrancesiessigloxxi',
#        'userName': 'departamentofrancesiessigloxxi',
#        'viewCount': 73954},
#       {'algorithmId': '5',
#        'displayTitle': 'Les repas',
#        'isSavedByCurrentUser': False,
#        'pageCount': 10,
#        'score': 0.607747,
#        'slideshowId': '10918526',
#        'sourceName': 'cm_interact',
#        'strippedTitle': 'les-repas-10918526',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lesrepas-120109155359-phpapp01-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': '',
#        'tags': ['civilisation', 'fle; français'],
#        'url': 'https://fr.slideshare.net/slideshow/les-repas-10918526/10918526',
#        'userLogin': 'cerines',
#        'userName': 'Ines Cerrato',
#        'viewCount': 44525},
#       {'algorithmId': '5',
#        'displayTitle': 'Fiche de travail: La cuisine française',
#        'isSavedByCurrentUser': False,
#        'pageCount': 2,
#        'score': 0.604725,
#        'slideshowId': '62240069',
#        'sourceName': 'cm_interact',
#        'strippedTitle': 'fiche-de-travail-la-cuisine-franaise-62240069',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/fichedetravailfrenchcuisine-160520200525-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': "Les élèves à travers les trois activités de la fiche de travail proposée doivent trouver des informations sur quatre recettes de la cuisine française: La salade niçoise, Le coq au vin, La soupe à l'oignon et La quiche lorraine. Ils doivent visiter trois sites web: Cuisine-Française, Wikipedia & Youtube",
#        'tags': ['gastronomie', "la soupe à l'oignon", 'ingredients'],
#        'url': 'https://fr.slideshare.net/akossyv/fiche-de-travail-la-cuisine-franaise-62240069',
#        'userLogin': 'akossyv',
#        'userName': 'Athina KOSSYVAKI',
#        'viewCount': 1326},
#       {'algorithmId': '5',
#        'displayTitle': 'Les instruments de musique',
#        'isSavedByCurrentUser': False,
#        'pageCount': 16,
#        'score': 0.603773,
#        'slideshowId': '31772723',
#        'sourceName': 'cm_interact',
#        'strippedTitle': 'les-instruments-de-musique-31772723',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lesinstrumentsdemusique-140228120449-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': '',
#        'tags': [],
#        'url': 'https://fr.slideshare.net/slideshow/les-instruments-de-musique-31772723/31772723',
#        'userLogin': 'departamentofrancesiessigloxxi',
#        'userName': 'departamentofrancesiessigloxxi',
#        'viewCount': 136547},
#       {'algorithmId': '5',
#        'displayTitle': 'Les verbes français',
#        'isSavedByCurrentUser': False,
#        'pageCount': 18,
#        'score': 0.60334,
#        'slideshowId': '7406084',
#        'sourceName': 'cm_interact',
#        'strippedTitle': 'les-verbes-franais',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lesverbesfranais-110327121126-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': "L'indicatif présent des trois groupes verbaux français",
#        'tags': [],
#        'url': 'https://fr.slideshare.net/slideshow/les-verbes-franais/7406084',
#        'userLogin': 'FFCV',
#        'userName': 'FFCV',
#        'viewCount': 14330},
#       {'algorithmId': '5',
#        'displayTitle': 'avoir expressions',
#        'isSavedByCurrentUser': False,
#        'pageCount': 14,
#        'score': 0.599403,
#        'slideshowId': '30659012',
#        'sourceName': 'cm_interact',
#        'strippedTitle': 'avoir-expressions-30659012',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/kashvif-140131033929-phpapp01-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'The document discusses the French verb "avoir" which literally means "to have" but is also used in many idiomatic expressions to describe states of being. It provides examples of common expressions using "avoir" that translate to "to be" in English, such as "avoir sommeil" (to feel sleepy), "avoir faim" (to be hungry), "avoir chaud" (to feel hot), and "avoir froid" (to feel cold). It then gives several example sentences in French using these expressions and their English translations.',
#        'tags': ['avoir', 'french', 'expressions'],
#        'url': 'https://www.slideshare.net/slideshow/avoir-expressions-30659012/30659012',
#        'userLogin': 'radhikakhatter',
#        'userName': 'Radhika Khatter',
#        'viewCount': 2143},
#       {'algorithmId': '5',
#        'displayTitle': 'LES PIÈCES DE LA MAISON.pdf',
#        'isSavedByCurrentUser': False,
#        'pageCount': 1,
#        'score': 0.597355,
#        'slideshowId': '259608446',
#        'sourceName': 'cm_interact',
#        'strippedTitle': 'les-pices-de-la-maisonpdf',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lespices-230804072908-8dd64949-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'Les pièces de la maison (A2)',
#        'tags': ['les pièces de la maison', 'la maison', 'vocabulaire fle'],
#        'url': 'https://fr.slideshare.net/slideshow/les-pices-de-la-maisonpdf/259608446',
#        'userLogin': 'lebaobabbleu',
#        'userName': 'lebaobabbleu',
#        'viewCount': 14269},
#       {'algorithmId': '5',
#        'displayTitle': 'Ma Trousse',
#        'isSavedByCurrentUser': False,
#        'pageCount': 11,
#        'score': 0.596792,
#        'slideshowId': '14603346',
#        'sourceName': 'cm_interact',
#        'strippedTitle': 'ma-trousseunite2',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/matrousseunite2-121005090130-phpapp01-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': "French vocabulary for what's inside your pencil case. Geared for 4th o4 5th grade.",
#        'tags': ['french language', 'ma trousse', 'pencil case'],
#        'url': 'https://fr.slideshare.net/slideshow/ma-trousseunite2/14603346',
#        'userLogin': 'afternoonmoon',
#        'userName': 'Allison Albino',
#        'viewCount': 2991},
#       {'algorithmId': '5',
#        'displayTitle': 'Les loisirs (A2)',
#        'isSavedByCurrentUser': False,
#        'pageCount': 1,
#        'score': 0.595772,
#        'slideshowId': '123136999',
#        'sourceName': 'cm_interact',
#        'strippedTitle': 'les-loisirs-a2',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lesloisirs-181115222319-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'Lexique pour travailler les loisirs (A2)',
#        'tags': ['les loisirs', 'fle', 'lexique fle'],
#        'url': 'https://fr.slideshare.net/lebaobabbleu/les-loisirs-a2',
#        'userLogin': 'lebaobabbleu',
#        'userName': 'lebaobabbleu',
#        'viewCount': 23017},
#       {'algorithmId': '5',
#        'displayTitle': 'Les prepositions de lieu et les noms des pays et des villes',
#        'isSavedByCurrentUser': False,
#        'pageCount': 8,
#        'score': 0.595072,
#        'slideshowId': '54284094',
#        'sourceName': 'cm_interact',
#        'strippedTitle': 'les-prepositions-de-lieu-et-les-noms-des-pays-et-des-villes',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lesprepositionsdelieuetlesnomsdespaysetdesvilles-151022225254-lva1-app6892-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'Les prépositions de lieu et les noms des pays et des villes',
#        'tags': ['pays', 'prepositions', 'lieu'],
#        'url': 'https://fr.slideshare.net/slideshow/les-prepositions-de-lieu-et-les-noms-des-pays-et-des-villes/54284094',
#        'userLogin': 'frptsol',
#        'userName': 'Paulo Marques',
#        'viewCount': 4623},
#       {'algorithmId': '5',
#        'displayTitle': 'Des specialites francaises',
#        'isSavedByCurrentUser': False,
#        'pageCount': 15,
#        'score': 0.593355,
#        'slideshowId': '62216749',
#        'sourceName': 'cm_interact',
#        'strippedTitle': 'des-specialites-francaises',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/desspecialitesfrancaises-160520080801-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'Présentation de 7 recettes de la cuisine française très connues',
#        'tags': ['sites web', 'cuisine', 'recette'],
#        'url': 'https://fr.slideshare.net/akossyv/des-specialites-francaises',
#        'userLogin': 'akossyv',
#        'userName': 'Athina KOSSYVAKI',
#        'viewCount': 2466},
#       {'algorithmId': '5',
#        'displayTitle': 'La musique et vous (B1)',
#        'isSavedByCurrentUser': False,
#        'pageCount': 13,
#        'score': 0.589034,
#        'slideshowId': '81230784',
#        'sourceName': 'cm_interact',
#        'strippedTitle': 'la-musique-et-vous-b1',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/ud2-lamusiqueetvouspartie2-171026075921-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'Unité didactique pour travailler le thème de la musique (B1)',
#        'tags': ['la musique fle',
#         'parler de la musique fle',
#         'la musique et vous fle'],
#        'url': 'https://fr.slideshare.net/slideshow/la-musique-et-vous-b1/81230784',
#        'userLogin': 'lebaobabbleu',
#        'userName': 'lebaobabbleu',
#        'viewCount': 19297},
#       {'algorithmId': '5',
#        'displayTitle': 'UD5: les fêtes et les célébrations (B1)',
#        'isSavedByCurrentUser': False,
#        'pageCount': 19,
#        'score': 0.589011,
#        'slideshowId': '86867472',
#        'sourceName': 'cm_interact',
#        'strippedTitle': 'ud5-les-ftes-et-les-clbrations-b1',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/unit10-lesftesetlesclbrationsdef-180129183420-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'Unité didactque pour travailler le thème des fêtes et célébrations',
#        'tags': ['les fêtes fle', 'les célébrations fle', 'les coutumes fle'],
#        'url': 'https://fr.slideshare.net/slideshow/ud5-les-ftes-et-les-clbrations-b1/86867472',
#        'userLogin': 'lebaobabbleu',
#        'userName': 'lebaobabbleu',
#        'viewCount': 12280},
#       {'algorithmId': '5',
#        'displayTitle': 'Indiquer la destination et la provenance (A1)',
#        'isSavedByCurrentUser': False,
#        'pageCount': 1,
#        'score': 0.588436,
#        'slideshowId': '60717719',
#        'sourceName': 'cm_interact',
#        'strippedTitle': 'indiquer-la-destination-et-la-provenance-a1',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/indiquerladestinationetlaprovenance-160410153402-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'Indiquer la destination et la provenance (A1)',
#        'tags': ['grammaire a1',
#         'indiquer la destination et la provenance',
#         'grammaire francaise'],
#        'url': 'https://fr.slideshare.net/lebaobabbleu/indiquer-la-destination-et-la-provenance-a1',
#        'userLogin': 'lebaobabbleu',
#        'userName': 'lebaobabbleu',
#        'viewCount': 14833},
#       {'algorithmId': '5',
#        'displayTitle': "A1 Les mois de l'année",
#        'isSavedByCurrentUser': False,
#        'pageCount': 14,
#        'score': 0.588336,
#        'slideshowId': '1739703',
#        'sourceName': 'cm_interact',
#        'strippedTitle': 'a1-les-mois-de-lanne',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/1739703-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': '',
#        'tags': [],
#        'url': 'https://fr.slideshare.net/slideshow/a1-les-mois-de-lanne/1739703',
#        'userLogin': 'jeancharles',
#        'userName': 'Jean-Charles Blondeau',
#        'viewCount': 7046},
#       {'algorithmId': '5',
#        'displayTitle': 'Lexique- le logement (A2)',
#        'isSavedByCurrentUser': False,
#        'pageCount': 1,
#        'score': 0.586645,
#        'slideshowId': '123973922',
#        'sourceName': 'cm_interact',
#        'strippedTitle': 'lexique-le-logement-a2',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lexique-lelogement-181125224927-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'Lexique pour travailler le thème du logement (A2)',
#        'tags': ['le logement', 'lexique fle', 'vocabulaire fle'],
#        'url': 'https://fr.slideshare.net/slideshow/lexique-le-logement-a2/123973922',
#        'userLogin': 'lebaobabbleu',
#        'userName': 'lebaobabbleu',
#        'viewCount': 18869},
#       {'algorithmId': '5',
#        'displayTitle': 'UN REPAS AU RESTAURANT',
#        'isSavedByCurrentUser': False,
#        'pageCount': 7,
#        'score': 0.585626,
#        'slideshowId': '61833494',
#        'sourceName': 'cm_interact',
#        'strippedTitle': 'un-repas-au-restaurant',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/aurestaurantjudelouis-160509204204-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'Objectifs fonctionnels: - arriver au restaurant. / - passer une commande. - Demander le menu  / la carte.\r\nObjectifs socioculturels: - menus et plats français.\r\n',
#        'tags': [],
#        'url': 'https://fr.slideshare.net/slideshow/un-repas-au-restaurant/61833494',
#        'userLogin': 'francaisjudelouis',
#        'userName': 'jude louis',
#        'viewCount': 18229},
#       {'algorithmId': '5',
#        'displayTitle': 'La négation',
#        'isSavedByCurrentUser': False,
#        'pageCount': 2,
#        'score': 0.582561,
#        'slideshowId': '18358037',
#        'sourceName': 'cm_interact',
#        'strippedTitle': 'la-ngation-18358037',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/langation-130407111207-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': '',
#        'tags': [],
#        'url': 'https://fr.slideshare.net/slideshow/la-ngation-18358037/18358037',
#        'userLogin': 'belge21',
#        'userName': 'belge21',
#        'viewCount': 5444},
#       {'algorithmId': '5',
#        'displayTitle': 'La négation',
#        'isSavedByCurrentUser': False,
#        'pageCount': 10,
#        'score': 0.582044,
#        'slideshowId': '39804276',
#        'sourceName': 'cm_interact',
#        'strippedTitle': 'langation-140114103524phpapp01141002102332phpapp02',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/langation-140114103524-phpapp01-141002102332-phpapp02-141002104007-phpapp01-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'Présentation sur les structures de la phrase négative en français.',
#        'tags': ['français', 'grammar', 'grammaire'],
#        'url': 'https://fr.slideshare.net/slideshow/langation-140114103524phpapp01141002102332phpapp02/39804276',
#        'userLogin': 'syndi91',
#        'userName': 'Syndi Valbuena',
#        'viewCount': 2757},
#       {'algorithmId': '5',
#        'displayTitle': 'Parler du caractère, de la personnalité (B1+)',
#        'isSavedByCurrentUser': False,
#        'pageCount': 5,
#        'score': 0.581729,
#        'slideshowId': '80866415',
#        'sourceName': 'cm_interact',
#        'strippedTitle': 'parler-du-caractre-de-la-personnalit-b1',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/parlerducaractredelapersonnalit-171016170847-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'Lexique + exercices',
#        'tags': ['le caractère', 'la personnalité', 'fle'],
#        'url': 'https://fr.slideshare.net/slideshow/parler-du-caractre-de-la-personnalit-b1/80866415',
#        'userLogin': 'lebaobabbleu',
#        'userName': 'lebaobabbleu',
#        'viewCount': 113514}],
#      'alsoLiked': [{'algorithmId': '21',
#        'displayTitle': 'La cuisine française',
#        'isSavedByCurrentUser': False,
#        'pageCount': 56,
#        'score': 0,
#        'slideshowId': '32236561',
#        'sourceName': 'li_interact',
#        'strippedTitle': 'la-cuisine-franaise-32236561',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lacuisinefranaise-140312133102-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': '',
#        'tags': [],
#        'url': 'https://www.slideshare.net/slideshow/la-cuisine-franaise-32236561/32236561',
#        'userLogin': 'Luciagruiz',
#        'userName': 'Luciagruiz',
#        'viewCount': 3693},
#       {'algorithmId': '21',
#        'displayTitle': 'LA CUISINE FRANÇAISE ',
#        'isSavedByCurrentUser': False,
#        'pageCount': 57,
#        'score': 0,
#        'slideshowId': '32238758',
#        'sourceName': 'li_interact',
#        'strippedTitle': 'la-cuisine-franaise-32238758',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/presentacin1-140312142614-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'LA CUISINE FRANÇAISE \r\n',
#        'tags': ['français la cuisine la cuisine française'],
#        'url': 'https://fr.slideshare.net/slideshow/la-cuisine-franaise-32238758/32238758',
#        'userLogin': 'Mariagarc',
#        'userName': 'Mariagarc',
#        'viewCount': 3374},
#       {'algorithmId': '21',
#        'displayTitle': 'La Cuisine Française',
#        'isSavedByCurrentUser': False,
#        'pageCount': 29,
#        'score': 0,
#        'slideshowId': '48893513',
#        'sourceName': 'li_interact',
#        'strippedTitle': 'la-cuisine-franaise-48893513',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/a-3-3e1751e032a8a6b019c04d0e8e8cad4a679c941c-150602141814-lva1-app6892-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'This short document promotes the creation of Haiku Deck presentations on SlideShare, stating that users can make their own Haiku Deck presentations on the SlideShare platform if they feel inspired. It provides a button to "GET STARTED" in making a Haiku Deck presentation on SlideShare.',
#        'tags': ['haikudeck'],
#        'url': 'https://www.slideshare.net/slideshow/la-cuisine-franaise-48893513/48893513',
#        'userLogin': 'frenchproject1',
#        'userName': 'frenchproject1',
#        'viewCount': 304},
#       {'algorithmId': '21',
#        'displayTitle': 'La Gastronomie FrançAise',
#        'isSavedByCurrentUser': False,
#        'pageCount': 35,
#        'score': 0,
#        'slideshowId': '2423540',
#        'sourceName': 'li_interact',
#        'strippedTitle': 'la-gastronomie-franaise-2423540',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lagastronomiefranaise-091104144714-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'Présentation des plats typiques de la France',
#        'tags': [],
#        'url': 'https://www.slideshare.net/slideshow/la-gastronomie-franaise-2423540/2423540',
#        'userLogin': 'Belami77',
#        'userName': 'Ismael Navarro Solera',
#        'viewCount': 44280},
#       {'algorithmId': '21',
#        'displayTitle': '2_francés',
#        'isSavedByCurrentUser': False,
#        'pageCount': 13,
#        'score': 0,
#        'slideshowId': '4614915',
#        'sourceName': 'li_interact',
#        'strippedTitle': '2francs',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/anamaria-100625132434-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': '',
#        'tags': [],
#        'url': 'https://fr.slideshare.net/slideshow/2francs/4614915',
#        'userLogin': 'NuevasTecnolg',
#        'userName': 'NuevasTecnolg',
#        'viewCount': 410},
#       {'algorithmId': '21',
#        'displayTitle': 'La cuisine de français',
#        'isSavedByCurrentUser': False,
#        'pageCount': 16,
#        'score': 0,
#        'slideshowId': '31136230',
#        'sourceName': 'li_interact',
#        'strippedTitle': 'la-cuisine-de-francais',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lacuisinedefrancais-140212125628-phpapp01-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'The French cuisine is extremely diverse and uses fresh, local ingredients. Meals consist of many courses and are a time for socializing. A typical breakfast includes bread, croissants, jam, and butter while lunch varies by region but usually includes wine. Dinner is the main meal, usually consisting of an appetizer, main dish like meat or fish with sides, cheese course, dessert, and coffee. Each course is prepared with care and accompanied by wine. Popular Parisian restaurants emphasize classic French fare or more innovative cooking styles.',
#        'tags': [],
#        'url': 'https://www.slideshare.net/slideshow/la-cuisine-de-francais/31136230',
#        'userLogin': 'cabbott21w',
#        'userName': 'cabbott21w',
#        'viewCount': 1098},
#       {'algorithmId': '21',
#        'displayTitle': 'Le repas gastronomique français',
#        'isSavedByCurrentUser': False,
#        'pageCount': 5,
#        'score': 0,
#        'slideshowId': '10381881',
#        'sourceName': 'li_interact',
#        'strippedTitle': 'le-repas-gastronomique-franais',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lerepasgastronomiquefranais-111129062146-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'Séquence pédagogique NIVEAU A1 sur le repas gastronomique à la française',
#        'tags': ['la carolina', 'a1', 'gastronomie'],
#        'url': 'https://fr.slideshare.net/slideshow/le-repas-gastronomique-franais/10381881',
#        'userLogin': 'IsabelMontesEOI',
#        'userName': 'Escuela Oficial de Idiomas La Carolina, Département de Français',
#        'viewCount': 5350},
#       {'algorithmId': '21',
#        'displayTitle': 'Cuisine francaise',
#        'isSavedByCurrentUser': False,
#        'pageCount': 10,
#        'score': 0,
#        'slideshowId': '9745934',
#        'sourceName': 'li_interact',
#        'strippedTitle': 'cuisine-francaise',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/cuisinefrancaise-111018060012-phpapp01-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': '',
#        'tags': [],
#        'url': 'https://fr.slideshare.net/slideshow/cuisine-francaise/9745934',
#        'userLogin': 'OlgaFernndezOrtega',
#        'userName': 'Olga Fernández Ortega',
#        'viewCount': 986},
#       {'algorithmId': '21',
#        'displayTitle': 'Cultural security in the age of globalization, the case of Middle East',
#        'isSavedByCurrentUser': False,
#        'pageCount': 51,
#        'score': 0,
#        'slideshowId': '47158184',
#        'sourceName': 'li_interact',
#        'strippedTitle': 'cultural-security-in-the-age-of-globalization-the-case-of-middle-east',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/teamwork-150419033327-conversion-gate02-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'People in Middle Eastern countries are concerned that globalization is threatening their culture, language, and traditions. Younger people are especially vulnerable as they increasingly adopt American pop culture through media and consumer products that symbolize concepts like freedom and modernity. Several Middle Eastern governments and media companies have also been introducing Western media to the region. However, some efforts are being made to adapt global influences to local culture, such as through Arabic-dubbed cartoons and movies, and new fashion trends fusing Western and Islamic styles. Researchers are studying how targeting cultural sites has become a tactic in regional conflicts like Syria, and international organizations are working with local experts to protect cultural heritage at risk.',
#        'tags': ['middle east', 'syria', 'isil'],
#        'url': 'https://www.slideshare.net/slideshow/cultural-security-in-the-age-of-globalization-the-case-of-middle-east/47158184',
#        'userLogin': 'nuriagulieva',
#        'userName': 'Nuriyya Guliyeva',
#        'viewCount': 981},
#       {'algorithmId': '21',
#        'displayTitle': 'Family relationships in Asia',
#        'isSavedByCurrentUser': False,
#        'pageCount': 16,
#        'score': 0,
#        'slideshowId': '46412396',
#        'sourceName': 'li_interact',
#        'strippedTitle': 'family-relationships-in-asia',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/familyrelationshipinasia-150329050051-conversion-gate01-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'Asian parents believe that disciplining children and obedience to parents prevents corruption, as explained by a Vietnamese proverb. Traditionally, Asian cultures assign different roles and treatment to girls and boys. Girls are expected to help with childcare and household chores, which can interfere with school attendance, while boys are given more freedom to play. Education was historically prioritized for boys over girls in some Asian cultures.',
#        'tags': ['relationships', 'asia', 'family'],
#        'url': 'https://www.slideshare.net/slideshow/family-relationships-in-asia/46412396',
#        'userLogin': 'nuriagulieva',
#        'userName': 'Nuriyya Guliyeva',
#        'viewCount': 682},
#       {'algorithmId': '21',
#        'displayTitle': 'Reference for Marialis Simoni from Kieran Daly',
#        'isSavedByCurrentUser': False,
#        'pageCount': 1,
#        'score': 0,
#        'slideshowId': '51731822',
#        'sourceName': 'li_interact',
#        'strippedTitle': 'reference-for-marialis-simoni-from-kieran-daly',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/ac35bfca-1b88-43bc-ae60-057ee20d0591-150817182140-lva1-app6892-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': '',
#        'tags': [],
#        'url': 'https://www.slideshare.net/slideshow/reference-for-marialis-simoni-from-kieran-daly/51731822',
#        'userLogin': 'MarialisSimoni',
#        'userName': 'Marialis Simoni',
#        'viewCount': 155},
#       {'algorithmId': '21',
#        'displayTitle': 'Social implications of globalization in Iran',
#        'isSavedByCurrentUser': False,
#        'pageCount': 22,
#        'score': 0,
#        'slideshowId': '45020246',
#        'sourceName': 'li_interact',
#        'strippedTitle': 'social-implications-of-globalization-in-iran',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/socialimplicationsofglobalizationiniran1-150223080647-conversion-gate01-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': "Globalization has impacted Iranian society in several ways. While the government has tried to resist some aspects of globalization to preserve local culture and values, Iranian society has increasingly engaged with global trends and technologies. This has led to changes in employment, migration patterns, gender roles, and family structures. Youth have adopted global media and connectivity, while facing government censorship and restrictions online. Overall, Iranian society has navigated a complex relationship with globalizing forces and local traditions amidst the government's efforts to control cultural changes.",
#        'tags': [],
#        'url': 'https://www.slideshare.net/slideshow/social-implications-of-globalization-in-iran/45020246',
#        'userLogin': 'nuriagulieva',
#        'userName': 'Nuriyya Guliyeva',
#        'viewCount': 3166},
#       {'algorithmId': '21',
#        'displayTitle': 'Academic Reference for Marialis Simoni from Klaus Suhling',
#        'isSavedByCurrentUser': False,
#        'pageCount': 1,
#        'score': 0,
#        'slideshowId': '51731762',
#        'sourceName': 'li_interact',
#        'strippedTitle': 'academic-reference-for-marialis-simoni-from-klaus-suhling',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/4b9a08ea-f4b9-4372-8b2a-0a7a2e71130e-150817182006-lva1-app6892-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'Klaus Suhling is writing a letter of recommendation for Marialis Simoni. Suhling taught Simoni in a first year Physics Skills course, which Simoni regularly attended and obtained an overall first class mark of 79% in. Simoni obtained an average of 82.8% in his first year, coming 7th out of more than 122 students, putting him on course for a first class honors degree. Suhling found Simoni to be a highly motivated, quick learning student who grasps novel ideas well. Suhling also described Simoni as friendly, mature, reliable, and responsible in their dealings, with a personality that makes him pleasant to work with.',
#        'tags': [],
#        'url': 'https://www.slideshare.net/slideshow/academic-reference-for-marialis-simoni-from-klaus-suhling/51731762',
#        'userLogin': 'MarialisSimoni',
#        'userName': 'Marialis Simoni',
#        'viewCount': 1289},
#       {'algorithmId': '21',
#        'displayTitle': 'The archival heritage \x0bof the Middle East. \x0b\x0bCurrent threats and scenarios fo...',
#        'isSavedByCurrentUser': False,
#        'pageCount': 12,
#        'score': 0,
#        'slideshowId': '55776155',
#        'sourceName': 'li_interact',
#        'strippedTitle': 'the-archival-heritage-of-the-middle-east-current-threats-and-scenarios-for-protection-in-the-future',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/thomasaignerworkshopmiddleeast-151203110108-lva1-app6891-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'Presentation by Thomas Aigner (President ICARUS) given within the international workshop "Archive material in the Middle East between menace and solidarity" on 24 November 2015 at the ICARUS-Meeting #16 in St. Pölten (AT).',
#        'tags': ['icarus-meeting', 'thomas aigner', 'icarus-meeting #16'],
#        'url': 'https://www.slideshare.net/slideshow/the-archival-heritage-of-the-middle-east-current-threats-and-scenarios-for-protection-in-the-future/55776155',
#        'userLogin': 'icaruseu',
#        'userName': 'ICARUS - International Centre for Archival Research',
#        'viewCount': 570},
#       {'algorithmId': '21',
#        'displayTitle': 'Academic Reference for Marialis Simoni from Nicola Bonini',
#        'isSavedByCurrentUser': False,
#        'pageCount': 1,
#        'score': 0,
#        'slideshowId': '51731781',
#        'sourceName': 'li_interact',
#        'strippedTitle': 'academic-reference-for-marialis-simoni-from-nicola-bonini',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/a36fe134-9382-4abd-9a74-ea282788067c-150817182035-lva1-app6892-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': "This letter provides a recommendation for Mr. Marialis Simoni from his personal tutor and lecturer Nicola Bonini. The letter states that Mr. Simoni has regularly attended lectures and labs in his first year physics degree at King's College London with great interest and dedication. His performance was excellent, with marks above 90% in multiple courses. The letter strongly supports Mr. Simoni's application and offers to provide any additional information needed.",
#        'tags': [],
#        'url': 'https://www.slideshare.net/slideshow/academic-reference-for-marialis-simoni-from-nicola-bonini/51731781',
#        'userLogin': 'MarialisSimoni',
#        'userName': 'Marialis Simoni',
#        'viewCount': 3476},
#       {'algorithmId': '21',
#        'displayTitle': 'Repas français',
#        'isSavedByCurrentUser': False,
#        'pageCount': 16,
#        'score': 0,
#        'slideshowId': '44458518',
#        'sourceName': 'li_interact',
#        'strippedTitle': 'repas-franais',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/repasfranais-150209133138-conversion-gate01-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'Repas francais',
#        'tags': [],
#        'url': 'https://fr.slideshare.net/slideshow/repas-franais/44458518',
#        'userLogin': 'iessaavedra2011',
#        'userName': 'iessaavedra2011',
#        'viewCount': 2490},
#       {'algorithmId': '21',
#        'displayTitle': 'Cuisine Nationale Azerbaïdjanaise',
#        'isSavedByCurrentUser': False,
#        'pageCount': 11,
#        'score': 0,
#        'slideshowId': '46412518',
#        'sourceName': 'li_interact',
#        'strippedTitle': 'cuisine-nationale-azerbadjanaise',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/cuisinenationaleazerbadjanaise-150329051128-conversion-gate01-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'Cuisine Nationale Azerbaïdjanaise',
#        'tags': [],
#        'url': 'https://www.slideshare.net/slideshow/cuisine-nationale-azerbadjanaise/46412518',
#        'userLogin': 'nuriagulieva',
#        'userName': 'Nuriyya Guliyeva',
#        'viewCount': 727},
#       {'algorithmId': '21',
#        'displayTitle': 'French Presentation',
#        'isSavedByCurrentUser': False,
#        'pageCount': 13,
#        'score': 0,
#        'slideshowId': '15525870',
#        'sourceName': 'li_interact',
#        'strippedTitle': 'french-presentation-15525870',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/frenchpresentation-121206180700-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': '',
#        'tags': [],
#        'url': 'https://fr.slideshare.net/slideshow/french-presentation-15525870/15525870',
#        'userLogin': 'jaimebeck',
#        'userName': 'jaimebeck',
#        'viewCount': 818},
#       {'algorithmId': '21',
#        'displayTitle': 'Academic recommendation letter',
#        'isSavedByCurrentUser': False,
#        'pageCount': 1,
#        'score': 0,
#        'slideshowId': '7675832',
#        'sourceName': 'li_interact',
#        'strippedTitle': 'academic-recommendation-letter',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/scan0414000-13032283536258-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'Recommendation letter from the Dean of Engineering Assistant',
#        'tags': [],
#        'url': 'https://www.slideshare.net/slideshow/academic-recommendation-letter/7675832',
#        'userLogin': 'uzquiano88',
#        'userName': 'Andres',
#        'viewCount': 14769},
#       {'algorithmId': '21',
#        'displayTitle': 'Letters of recomendation',
#        'isSavedByCurrentUser': False,
#        'pageCount': 6,
#        'score': 0,
#        'slideshowId': '3785230',
#        'sourceName': 'li_interact',
#        'strippedTitle': 'letters-of-recomendation',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lettersofrecomendation-100420014611-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': "The document is a letter from Steve Pallister of BP Azerbaijan recommending Water Engineered Technology (WET) for their water filtration and purification systems. BP has used WET's systems for 3 years at their Sangachal Terminal, serving over 5,000 workers. WET has proven themselves with reliable installation, maintenance and monitoring of the systems. Pallister has no hesitation recommending WET's technology and services to other prospective customers.",
#        'tags': ['letters', 'recommendation'],
#        'url': 'https://www.slideshare.net/slideshow/letters-of-recomendation/3785230',
#        'userLogin': 'wetint',
#        'userName': 'Vladimir',
#        'viewCount': 40331}],
#      'similarTo': [{'algorithmId': '3',
#        'displayTitle': 'La  Gastronomie FrançAise',
#        'isSavedByCurrentUser': False,
#        'pageCount': 17,
#        'score': 0.5176,
#        'slideshowId': '2899222',
#        'sourceName': 'cm_text',
#        'strippedTitle': 'la-gastronomie-franaise-2899222',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lagastronomiefranaise-100112162614-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'Presentation réalisée par Macarena Ortega et Pilar Muñoz',
#        'tags': [],
#        'url': 'https://fr.slideshare.net/slideshow/la-gastronomie-franaise-2899222/2899222',
#        'userLogin': 'francessantacatalina',
#        'userName': 'francessantacatalina',
#        'viewCount': 2223},
#       {'algorithmId': '3',
#        'displayTitle': 'French Culture',
#        'isSavedByCurrentUser': False,
#        'pageCount': 17,
#        'score': 0.5,
#        'slideshowId': '30402628',
#        'sourceName': 'cm_text',
#        'strippedTitle': 'french-culture-30402628',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/french-140124143212-phpapp01-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': '',
#        'tags': ['culture'],
#        'url': 'https://fr.slideshare.net/slideshow/french-culture-30402628/30402628',
#        'userLogin': 'clavinrali',
#        'userName': 'Clavin Rali',
#        'viewCount': 914},
#       {'algorithmId': '3',
#        'displayTitle': 'La gastronomie francaise. Elsa Alcázar. 2ºBc',
#        'isSavedByCurrentUser': False,
#        'pageCount': 49,
#        'score': 0.4742,
#        'slideshowId': '6131828',
#        'sourceName': 'cm_text',
#        'strippedTitle': 'la-gastronomie-francaise-elsa-alczar-2bc',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/lagastronomiefrancaise-101212144609-phpapp02-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': '',
#        'tags': ['gastronomie', 'fle', 'eoi'],
#        'url': 'https://fr.slideshare.net/slideshow/la-gastronomie-francaise-elsa-alczar-2bc/6131828',
#        'userLogin': 'asola',
#        'userName': 'asola',
#        'viewCount': 2733},
#       {'algorithmId': '3',
#        'displayTitle': 'Presentación1',
#        'isSavedByCurrentUser': False,
#        'pageCount': 12,
#        'score': 0.4465,
#        'slideshowId': '36003174',
#        'sourceName': 'cm_text',
#        'strippedTitle': 'presentacin1-36003174',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/presentacin1-140618023123-phpapp01-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': '',
#        'tags': [],
#        'url': 'https://fr.slideshare.net/slideshow/presentacin1-36003174/36003174',
#        'userLogin': 'JaimeRomeroBelda',
#        'userName': 'JaimeRomeroBelda',
#        'viewCount': 371},
#       {'algorithmId': '3',
#        'displayTitle': 'COCINA FRANCESA.pptx',
#        'isSavedByCurrentUser': False,
#        'pageCount': 12,
#        'score': 0.3974,
#        'slideshowId': '254613637',
#        'sourceName': 'cm_text',
#        'strippedTitle': 'cocina-francesapptx',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/cocinafrancesa-221130203246-11bf33e3-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'Powerpoint cocina francesa en francés',
#        'tags': [],
#        'url': 'https://fr.slideshare.net/slideshow/cocina-francesapptx/254613637',
#        'userLogin': 'RocioLuisRodriguez',
#        'userName': 'RocioLuisRodriguez',
#        'viewCount': 4},
#       {'algorithmId': '3',
#        'displayTitle': 'projekt la nourriture',
#        'isSavedByCurrentUser': False,
#        'pageCount': 21,
#        'score': 0.396,
#        'slideshowId': '58157554',
#        'sourceName': 'cm_text',
#        'strippedTitle': 'projekt-la-nourriture',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/frengjisht-anxhi-160211162658-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': 'punoi anxhela gjini \nle sujet:la nourriture',
#        'tags': [],
#        'url': 'https://fr.slideshare.net/slideshow/projekt-la-nourriture/58157554',
#        'userLogin': 'DajanaGjini',
#        'userName': 'Dajana Gjini',
#        'viewCount': 304},
#       {'algorithmId': '3',
#        'displayTitle': 'Yummy magazine N°17',
#        'isSavedByCurrentUser': False,
#        'pageCount': 68,
#        'score': 0.384,
#        'slideshowId': '50207861',
#        'sourceName': 'cm_text',
#        'strippedTitle': 'yummy-magazine-n17',
#        'thumbnail': 'https://cdn.slidesharecdn.com/ss_thumbnails/yummymagazinen17-150706113252-lva1-app6891-thumbnail.jpg?width=600&height=600&fit=bounds',
#        'description': "Le premier magazine gratuit, collaboratif et électronique des blogs culinaires. Au sommaire : Naturellement bon - Ils font le buzz : Les choux, L’orange, Les fèves, La mangue, L’ail frais, La rhubarbe - Rencontre avec… Arthur Le Caisne - Vite fait, bien fait ! Au quotidien - Le temps d'un week-end - British Corner - Sans gluten & sans lactose - Zoom sur Les cakes salés et sucrés - Histoire d’épices : La cardamome",
#        'tags': ['food', 'recettes', 'cuisine'],
#        'url': 'https://fr.slideshare.net/slideshow/yummy-magazine-n17/50207861',
#        'userLogin': 'YummyMagazine',
#        'userName': 'YummyMagazine',
#        'viewCount': 3453},
#       {'algorithmId': '3',
# ...
#         'unfollow': 'There was a problem un-following this user',
#         'save': 'Unable to save this item at this time.',
#         'remove_save': "We couldn't remove from your saved items"},
#        'header': {'hamburger_menu_aria_label': 'Open navigation menu',
#         'logo': {'alt': 'SlideShare a Scribd company logo',
#          'title': 'Return to the homepage'},
#         'home': 'Home',
#         'explore': 'Explore',
#         'search': {'placeholder': 'Search',
#          'aria_label': 'Search SlideShare',
#          'button': 'Submit Search'},
#         'upload': 'Upload',
#         'login': 'Login',
#         'signup': {'label': 'Download free for 30 days',
#          'title': 'Signup now for a SlideShare account'},
#         'user': {'aria_label': 'User Settings',
#          'clipboards': 'My Clipboards',
#          'uploads': 'My Uploads',
#          'analytics': 'Analytics',
#          'settings': 'Account Settings',
#          'support': 'Support',
#          'logout': 'Logout'},
#         'savedPopover': {'message': 'Your Saved items\nare here.',
#          'emojiAlt': 'Waving hand emoji'}},
#        'footer': {'link': {'about': 'About',
#          'support': 'Support',
#          'terms': 'Terms',
#          'privacy': 'Privacy',
#          'copyright': 'Copyright',
#          'cookie': 'Cookie Preferences',
#          'privacyRights': 'Do not sell or share my personal information'},
#         'language_selector': {'aria_label': 'Change Language',
#          'hidden_text': 'Current Language'},
#         'copyright': 'SlideShare from Scribd',
#         'social': {'rss': {'aria_label': 'Slideshare on RSS Feed',
#           'title': 'RSS'},
#          'twitter': {'aria_label': 'Slideshare on Twitter',
#           'title': 'Twitter'}}},
#        'app_notification_banner': {'notification_text': "We've updated our privacy policy.",
#         'notification_link_text_desktop': 'Click here to review the details.',
#         'notification_link_text_mobile': 'Tap here to review the details.'},
#        'privacy_policy_explicit_opt_in_modal': {'modal_title': "We've updated our privacy policy.",
#         'modal_content_paragraph_one': 'We’ve updated our privacy policy so that we are compliant with changing global privacy regulations and to provide you with insight into the limited ways in which we use your data.',
#         'modal_content_paragraph_two': 'You can read the details below. By accepting, you agree to the updated privacy policy.',
#         'modal_content_paragraph_three': 'Thank you!',
#         'modal_action_assertive': 'Accept and continue',
#         'modal_action': 'View updated privacy policy',
#         'modal_action_error': "We've encountered a problem, please try again."},
#        'actions': {'all_saved': 'All Saved',
#         'back': 'Back',
#         'close': 'Close',
#         'cancel': 'Cancel',
#         'save': 'Save',
#         'saved': 'Saved',
#         'next': 'Next',
#         'previous': 'Previous',
#         'scrollLeft': 'Scroll Left',
#         'scrollRight': 'Scroll Right',
#         'save_to_new_list_success': 'Saved to '},
#        'form': {'required': 'Required'},
#        'slideshow_card': {'slideshow_type': {'document': 'Document',
#          'infographic': 'Infographic',
#          'presentation': 'Presentation'},
#         'slideshow_type_unit': {'presentation': 'Slide',
#          'document': 'Page',
#          'infographic': 'Page'},
#         'pages_count_one': '{{count}} page',
#         'pages_count_other': '{{count}} pages',
#         'slides_count_one': '{{count}} slide',
#         'slides_count_other': '{{count}} slides',
#         'screen_reader_text': '{{title}} by {{author}}',
#         'screen_reader_text_extended': '{{title}} by {{author}}, has {{slideCount}} slides with {{viewCount}} views.'},
#        'image_alt': {'studying': 'Abstract image of a woman sitting on books and studying on a laptop'},
#        'items': {'count_one': '{{count}} item',
#         'count_other': '{{count}} items'},
#        'time': {'second_one': '{{count}} second',
#         'second_other': '{{count}} seconds'},
#        'timeSince': {'minutes_ago': '{{count}} min. ago',
#         'hours_ago_one': '{{count}} hour ago',
#         'hours_ago_other': '{{count}} hours ago',
#         'days_ago_one': '{{count}} day ago',
#         'days_ago_other': '{{count}} days ago',
#         'months_ago_one': '{{count}} month ago',
#         'months_ago_other': '{{count}} months ago',
#         'years_ago_one': '{{count}} year ago',
#         'years_ago_other': '{{count}} years ago'}},
#       'player': {'actions': {'all_saved': 'All Saved',
#         'clip': 'Clip Slide',
#         'download': 'Download',
#         'favorite': 'Favorite',
#         'remove_favorite': 'Remove favorite',
#         'remove_like': 'Remove like',
#         'like': 'Like',
#         'follow': 'Follow',
#         'unfollow': 'Unfollow',
#         'more_options': 'More options',
#         'share': 'Share',
#         'save': 'Save for later',
#         'save_slide': 'Save slide',
#         'saved': 'Saved',
#         'remove_saved': 'Remove save',
#         'remove_from_list': 'Remove from list {{listname}}',
#         'removed_from_list': 'Saved item has been removed from the List',
#         'removed_from_list_error': 'Could not remove the saved item from list',
#         'save_error': 'Unable to save this item at this time.',
#         'save_to_new_list': 'New list',
#         'save_to_list': 'Save to list {{listname}}',
#         'scroll_view': 'Scroll view',
#         'scroll_view_description': 'Vertically scroll through all slides',
#         'slideshow_view': 'Slideshow view',
#         'slideshow_view_description': 'View one slide at a time',
#         'no_saved_lists': "You don't have any lists created yet."},
#        'ads': {'label': 'Ad',
#         'skip': 'Skip to next slide',
#         'skip_countdown': 'You can skip to the next slide in',
#         'continue_in': 'Continue in',
#         'change_volume': 'Change Volume',
#         'go_adfree': 'Go ad-free on SlideShare',
#         'scroll': 'Scroll to read more'},
#        'ad_block_interstitial': {'title_1': 'Keep SlideShare free —',
#         'title_2': 'please disable your ad blocker.',
#         'button_label': 'Show me how',
#         'message': 'Hate ads? Join Scribd to browse SlideShare and Scribd ad-free.',
#         'cta': 'Try Scribd for free'},
#        'author': {'by': 'by',
#         'follow': 'Follow',
#         'following': 'Following',
#         'keynoteAuthor': 'Keynote Author'},
#        'download': {'success': 'Your SlideShare is downloading.'},
#        'editors_notes': "Editor's Notes",
#        'end_of_reading': {'loading': 'Loading in',
#         'title': 'Check these out next',
#         'next_slideshares': 'Next SlideShares',
#         'upcoming_slideshare': 'Upcoming SlideShare'},
#        'first_clip': {'title': 'You just clipped your first slide!',
#         'description': 'Clipping is a handy way to collect important slides you want to go back to later. Now customize the name of a clipboard to store your clips.'},
#        'metadata': {'at': 'at',
#         'aiTag': {'descriptionLabel': 'AI-enhanced description',
#          'descriptionTooltipTitle': 'AI-Enhanced Description',
#          'descriptionTooltip': "Leveraging AI technology, we've optimized the description for improved clarity.",
#          'titleLabel': 'AI-enhanced title',
#          'titleTooltipTitle': 'AI-Enhanced Title',
#          'titleTooltip': "Leveraging AI technology, we've optimized the title for improved clarity.",
#          'titleAndDescriptionLabel': 'AI-enhanced title and description',
#          'titleAndDescriptionTooltipTitle': 'AI-Enhanced Title and Description',
#          'titleAndDescriptionTooltip': "Leveraging AI technology, we've optimized the title and description for improved clarity."},
#         'download': {'bottomSheetTitle': 'Download format',
#          'label_short': 'Download',
#          'label': 'Download now',
#          'description': 'Download to read offline'},
#         'download_as': 'Download as {{formatTypes}}',
#         'readMore': 'Read more',
#         'readLess': 'Read less',
#         'more': 'more',
#         'category': {'label': 'Category',
#          'description': 'View the featured presentations, documents and infographics in the'},
#         'dateFormat': 'MMM. D, YYYY',
#         'most_read': 'Most read',
#         'pages': 'Pages',
#         'page': 'Page'},
#        'navigation': {'next_slide': 'Next Slide',
#         'previous_slide': 'Previous Slide',
#         'slide_count_of_total_count': "<span data-cy='current-slide-number' class='current-slide-number j-current-slide'>{{slideCount}}</span> of <span class='total-slides j-total-slides'>{{totalCount}}</span>",
#         'view_fullscreen': 'View Fullscreen',
#         'zoom_in': 'Zoom In',
#         'zoom_out': 'Zoom Out'},
#        'new_clipboard_modal': {'title': 'Create a clipboard',
#         'name': {'label': 'Name',
#          'placeholder': 'Best of Slides',
#          'error': 'Name cannot be blank'},
#         'description': {'label': 'Description',
#          'placeholder': 'Add a brief description so other know what your clipboard is about.'},
#         'visibility': {'label': 'Visibility',
#          'description': 'Others can see my Clipboard'}},
#        'select_clipboard_modal': {'title': 'Select a clipboard',
#         'message': "Looks like you've already clipped this slide",
#         'button': 'Create a clipboard'},
#        'share': 'Share SlideShare',
#        'rec': {'related': 'Related slideshows',
#         'recommended_for_you': 'Recommended for you',
#         'descTooltipTitle': 'About the slideshow',
#         'recommended': {'title': 'Recommended', 'shortTitle': 'Recommended'},
#         'relatedContent': {'title': 'More Related Content',
#          'shortTitle': 'More Related Content'},
#         'featured': {'title': 'Featured', 'shortTitle': 'Featured'},
#         'forYou': {'title': 'Slideshows for you',
#          'shortTitle': 'Slideshows for you'},
#         'alsoLiked': {'title': 'Viewers also liked',
#          'shortTitle': 'Viewers also liked'},
#         'latest': {'title': 'Recently uploaded',
#          'shortTitle': 'Recently uploaded'},
#         'moreFromUser': {'title': 'More from {{name}}',
#          'shortTitle': 'More from uploader'},
#         'similarTo': {'title': 'Similar to {{title}}',
#          'shortTitle': 'Similar to'},
#         'whatsHot': {'title': "What's hot", 'shortTitle': "What's hot"}},
#        'scribd': {'books': {'label': 'Ebook', 'title': 'Related Books'},
#         'audioBooks': {'label': 'Audiobook', 'title': 'Related Audiobooks'},
#         'error': {'title': 'Oops! Something went wrong.',
#          'description': "We're sorry, but we can't find any related content at this time.",
#          'button': 'Try again'},
#         'freeWithTrial': 'Free with a 30 day trial from {{brand}}',
#         'viewAll': 'View All'},
#        'error': {'clipboard': "We couldn't create your clipboard",
#         'save': "We couldn't save this item",
#         'unsave': "We couldn't remove from your saved items",
#         'blocked': 'This user has blocked you',
#         'private_content': 'Private content!',
#         'privacy_explanation': 'This content has been marked as private by the uploader.',
#         'enter_password': 'Enter password',
#         'file_protected': 'This file is password protected.',
#         'password_incorrect': 'The password is incorrect.',
#         'private_presentation': 'Private Presentation',
#         'private_content_message': 'This uploaded file has been marked private by the author. Sorry!',
#         'removed_content_title': 'Uploaded Content Removed',
#         'removed_content_message': 'The uploaded content has been removed and is no longer available.',
#         'redirect_message': 'Redirecting to the homepage in',
#         'something_went_wrong_title': 'Sorry! The page could not be loaded.',
#         'something_went_wrong_message': 'This is probably a temporary error. Just refresh the page and retry. If the problem continues, please check back in 5-10 minutes.',
#         'not_found_title': 'Sorry! We could not find what you were looking for.',
#         'not_found_message': "Don't worry, we will help you get to the right place. Are you looking for:"},
#        'save_to_new_list_modal': {'title': 'Add to a new list',
#         'list_name_input_label': 'What would you like to name this list?',
#         'list_privacy_label': 'Make list private',
#         'cancel_button_label': 'Cancel',
#         'save_list_button_label': 'Save',
#         'success': 'Saved to ',
#         'error': "We couldn't save this item to {{listname}}"},
#        'confirm_remove_save_modal': {'title': 'This saved item is also in a list.',
#         'description': 'Removing from saved will also delete the item from your lists',
#         'cancel_button_label': 'Cancel',
#         'delete_button_label': 'Delete'},
#        'seo_metadata_test': {'description_suffix': 'Download as a PDF or view online for free'}},
#       'metadata': {'like_one': 'like',
#        'like_other': 'likes',
#        'likeWithCount_one': '{{count}} like',
#        'likeWithCount_other': '{{count}} likes',
#        'view_one': 'view',
#        'view_other': 'views',
#        'saved_one': 'saved',
#        'saved_other': 'saved',
#        'from_embeds': 'From embeds',
#        'number_of_embeds': 'Number of embeds',
#        'on_slideshare': 'On Slideshare',
#        'total_views': 'Total views',
#        'split_char': ',',
#        'decimal_point': '.',
#        'show_more': 'Show More',
#        'likes': {'empty_message': 'Be the first to like this',
#         'loading_message': 'Loading...'},
#        'slide_one': 'slide',
#        'slide_other': 'slides',
#        'slide_count_of_total': 'of'},
#       'report': {'more': 'More options',
#        'share': 'Share',
#        'report': 'Report',
#        'edit': 'Edit',
#        'viewAnalytics': 'View Analytics',
#        'flag_as_inappropriate': 'Report as inappropriate',
#        'error': 'There was an error while reporting this slideshow. Please try again.',
#        'flag': 'Flag',
#        'copyright_complaint': 'Copyright Complaint',
#        'select_a_reason': 'Select a reason',
#        'select_your_reason': 'Select your reason for reporting this presentation as inappropriate.',
#        'none': 'None',
#        'porn': 'Pornographic',
#        'defamatory': 'Defamatory',
#        'ultraviolence': 'Extremely Violent or Promotes Terrorism',
#        'hate_speech': 'Hate Speech',
#        'offensive': 'Offensive Language or Threatening',
#        'spam': 'Spam or Scam'},
#       'share_modal': {'close': 'Close',
#        'embed_title': 'Embed',
#        'embed_size': 'Size (px)',
#        'link': 'Link',
#        'start': 'Start on',
#        'title': 'Share this SlideShare',
#        'share_facebook': 'Share on Facebook',
#        'share_linkedin': 'Share on Linkedin',
#        'share_twitter': 'Tweet on Twitter'},
#       'next_slideshow': {}}},
#     'initialLocale': 'fr',
#     'ns': ['common',
#      'player',
#      'metadata',
#      'report',
#      'share_modal',
#      'next_slideshow'],
#     'userConfig': None},
#    '_sentryTraceData': '1d65bcae71354c23bc2f94f12a2cb9e1-c772629f135445a4-1',
#    '_sentryBaggage': 'sentry-environment=production,sentry-public_key=7e7cafa2920448ed81ac67de08abbeed,sentry-trace_id=1d65bcae71354c23bc2f94f12a2cb9e1,sentry-sample_rate=1,sentry-transaction=%2Fslideshow%2F%5Btitle%5D%2F%5Bid%5D,sentry-sampled=true'},
#   '__N_SSP': True},
#  'page': '/slideshow/[title]/[id]',
#  'query': {'from_search': '0',
#   'title': 'repas-franais-46412448',
#   'id': '46412448'},
#  'buildId': 'a969437c5a494d59ad4aaff969615010ca15b095',
#  'assetPrefix': 'https://public.slidesharecdn.com',
#  'runtimeConfig': {'assetPrefix': 'https://public.slidesharecdn.com'},
#  'isFallback': False,
#  'isExperimentalCompile': False,
#  'dynamicIds': [33034],
#  'gssp': True,
#  'locale': 'fr',
#  'locales': ['en', 'de', 'es', 'pt', 'fr'],
#  'defaultLocale': 'fr',
#  'domainLocales': [{'domain': 'www.slideshare.net', 'defaultLocale': 'en'},
#   {'domain': 'de.slideshare.net', 'defaultLocale': 'de'},
#   {'domain': 'es.slideshare.net', 'defaultLocale': 'es'},
#   {'domain': 'pt.slideshare.net', 'defaultLocale': 'pt'},
#   {'domain': 'fr.slideshare.net', 'defaultLocale': 'fr'}],
#  'scriptLoader': []}

# %% [markdown]
# ## Scraping

# %%
#page_i is the url format of the content search page in French on slideshare
#the first page is page_i.format(1), the second page is page_2.format(2) etc...
#nb pages is the number of the last content search page that we scrap.
page_i = "https://fr.slideshare.net/search?searchfrom=header&q=fran%C3%A7ais&page={}"
nb_pages = 2

# %%
#Execution of the scraper
for i in range(1,nb_pages+1) :
    urls = extract_urls_from_search(page_i.format(i))
    for j,url in enumerate(urls) :
            sleep(2)
            scrap(url)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connection.py:196, in HTTPConnection._new_conn(self)
#     195 try:
# --> 196     sock = connection.create_connection(
#     197         (self._dns_host, self.port),
#     198         self.timeout,
#     199         source_address=self.source_address,
#     200         socket_options=self.socket_options,
#     201     )
#     202 except socket.gaierror as e:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] Une tentative de connexion a échoué car le parti connecté n’a pas répondu convenablement au-delà d’une certaine durée ou une connexion établie a échoué car l’hôte de connexion n’a pas répondu
#
# The above exception was the direct cause of the following exception:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connectionpool.py:490, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     489         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 490     raise new_e
#     492 # conn.request() calls http.client.*.request, not the method in
#     493 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     465 try:
# --> 466     self._validate_conn(conn)
#     467 except (SocketTimeout, BaseSSLError) as e:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connection.py:615, in HTTPSConnection.connect(self)
#     614 sock: socket.socket | ssl.SSLSocket
# --> 615 self.sock = sock = self._new_conn()
#     616 server_hostname: str = self.host
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connection.py:205, in HTTPConnection._new_conn(self)
#     204 except SocketTimeout as e:
# --> 205     raise ConnectTimeoutError(
#     206         self,
#     207         f"Connection to {self.host} timed out. (connect timeout={self.timeout})",
#     208     ) from e
#     210 except OSError as e:
#
# ConnectTimeoutError: (<urllib3.connection.HTTPSConnection object at 0x000001CE26974450>, 'Connection to image.slidesharecdn.com timed out. (connect timeout=None)')
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='image.slidesharecdn.com', port=443): Max retries exceeded with url: /27092023elabebfmtvlesfranaislessenceetlepouvoirdachatlesfranaisetleharclementscolaire-230927145320-defc4989/85/%20Les%20Fran%C3%A7ais,%20l%E2%80%99essence%20et%20le%20pouvoir%20d%E2%80%99achat%20/%20Les%20Fran%C3%A7ais%20et%20le%20harc%C3%A8lement%20scolaire-37-638.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001CE26974450>, 'Connection to image.slidesharecdn.com timed out. (connect timeout=None)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# Cell In[17], line 6
#       4 for j,url in enumerate(urls) :
#       5         sleep(2)
# ----> 6         scrap(url)
#
# Cell In[15], line 40, in scrap(url)
#      38 #For each image
#      39 for i in range(slideshow["totalSlides"]):
# ---> 40     response = requests.get(img_url.format(i+1))
#      41     sleep(5)
#      42     with open(f"data/{folder_name}/slide_{i}.jpg", "wb") as f :
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\requests\adapters.py:688, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     685 if isinstance(e.reason, ConnectTimeoutError):
#     686     # TODO: Remove this in 3.0.0: see #2811
#     687     if not isinstance(e.reason, NewConnectionError):
# --> 688         raise ConnectTimeout(e, request=request)
#     690 if isinstance(e.reason, ResponseError):
#     691     raise RetryError(e, request=request)
#
# ConnectTimeout: HTTPSConnectionPool(host='image.slidesharecdn.com', port=443): Max retries exceeded with url: /27092023elabebfmtvlesfranaislessenceetlepouvoirdachatlesfranaisetleharclementscolaire-230927145320-defc4989/85/%20Les%20Fran%C3%A7ais,%20l%E2%80%99essence%20et%20le%20pouvoir%20d%E2%80%99achat%20/%20Les%20Fran%C3%A7ais%20et%20le%20harc%C3%A8lement%20scolaire-37-638.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001CE26974450>, 'Connection to image.slidesharecdn.com timed out. (connect timeout=None)'))
